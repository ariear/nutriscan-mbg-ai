# %% [markdown]
# # Deteksi Dini Risiko Pola Makan Tidak Seimbang Melalui Analisis Visual Makanan pada Program MBG
#
# Kelas: `buah`, `karbohidrat`, `protein`, `sayur`, `susu`
# Model: U-Net + MobileNetV2 backbone + Fuzzy Logic Classifier

# %% [markdown]
# ## Instalasi & Import Library

# %%
# !pip install scikit-fuzzy opencv-python-headless pillow tqdm roboflow -q

# %%
import os
import json
import random
import shutil
import datetime
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from pathlib import Path
from tqdm import tqdm
from PIL import Image, ImageDraw

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import MobileNetV2
import tensorflow.keras.backend as K

import skfuzzy as fuzz
from skfuzzy import control as ctrl

from sklearn.model_selection import train_test_split
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.8/920.8 kB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 57.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 128.4 MB/s eta 0:00:00

# %% [markdown]
# ## Konfigurasi Dasar & Global Variabel

# %%
# Seed untuk reproduksibilitas
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Konfigurasi GPU
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f'GPU tersedia: {len(gpus)} GPU')
else:
    print('Menggunakan CPU')
# Out:
# GPU tersedia: 1 GPU

# %% [markdown]
# ## Download Dataset dari Roboflow

# %%
from roboflow import Roboflow

rf      = Roboflow(api_key="LAUgmCFfKK8FG1DqrJg0")
project = rf.workspace("iqbals-workspace-wjr03").project("ompreng-mbg-fix")
version = project.version(2)
dataset = version.download("tensorflow")

print("Dataset berhasil diunduh.")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Ompreng-MBG-Fix-2 to tensorflow:: 100%|██████████| 72656/72656 [00:01<00:00, 65810.08it/s]
# Extracting Dataset Version Zip to Ompreng-MBG-Fix-2 in tensorflow:: 100%|██████████| 1409/1409 [00:00<00:00, 4992.53it/s]
# Dataset berhasil diunduh.

# %% [markdown]
# ## Path, Hyperparameter & Class Mapping

# %%
# Path Dataset
BASE_DIR     = Path('Ompreng-MBG-Fix-2')

IMAGES_TRAIN = BASE_DIR / 'train'
MASKS_TRAIN  = BASE_DIR / 'train_masks'

IMAGES_VAL   = BASE_DIR / 'valid'
MASKS_VAL    = BASE_DIR / 'valid_masks'

IMAGES_TEST  = BASE_DIR / 'test'
MASKS_TEST   = BASE_DIR / 'test_masks'

METADATA_DIR = BASE_DIR / 'metadata'

MODEL_SAVE_PATH  = 'models/unet_mbg.keras'
FINAL_MODEL_PATH = 'models/unet_mbg_final.keras'
LOG_DIR          = 'logs/fit/' + datetime.datetime.now().strftime('%Y%m%d-%H%M%S')

# Hyperparameter
IMG_HEIGHT    = 256
IMG_WIDTH     = 256
IMG_CHANNELS  = 3
BATCH_SIZE    = 8
EPOCHS        = 50
LEARNING_RATE = 1e-4

# Class Mapping
CLASS_MAPPING = {
    0: 'background',
    1: 'buah',
    2: 'karbohidrat',
    3: 'protein',
    4: 'sayur',
    5: 'susu'
}
NUM_CLASSES = len(CLASS_MAPPING)

# Warna Visualisasi per Kelas
CLASS_COLORS = {
    0: [0,   0,   0  ],   # background  → hitam
    1: [255, 140, 0  ],   # buah        → oranye
    2: [240, 220, 80 ],   # karbohidrat → kuning
    3: [200, 80,  80 ],   # protein     → merah
    4: [50,  200, 50 ],   # sayur       → hijau
    5: [100, 190, 255],   # susu        → biru muda
}

# Mapping Kelas → Kategori Nutrisi
NUTRISI_MAPPING = {
    'buah'        : 'serat',
    'karbohidrat' : 'karbo',
    'protein'     : 'protein',
    'sayur'       : 'serat',
    'susu'        : 'susu',
}

# Membuat direktori yang dibutuhkan
for d in [METADATA_DIR, Path('models'), Path(LOG_DIR)]:
    d.mkdir(parents=True, exist_ok=True)

print(f'NUM_CLASSES  : {NUM_CLASSES}')
print(f'CLASS_MAPPING: {CLASS_MAPPING}')
# Out:
# NUM_CLASSES  : 6
# CLASS_MAPPING: {0: 'background', 1: 'buah', 2: 'karbohidrat', 3: 'protein', 4: 'sayur', 5: 'susu'}

# %% [markdown]
# ## Data Preparation : Generate Mask dari Anotasi Roboflow CSV

# %%
# Simpan class mapping ke metadata
class_mapping_str = {str(k): v for k, v in CLASS_MAPPING.items()}
metadata_file = METADATA_DIR / 'class_mapping.json'
with open(metadata_file, 'w') as f:
    json.dump(class_mapping_str, f, indent=2)

print(f'Metadata disimpan: {metadata_file}')
print(json.dumps(class_mapping_str, indent=2))
# Out:
# Metadata disimpan: Ompreng-MBG-Fix-2/metadata/class_mapping.json
# {
#   "0": "background",
#   "1": "buah",
#   "2": "karbohidrat",
#   "3": "protein",
#   "4": "sayur",
#   "5": "susu"
# }

# %%
def generate_masks_from_csv(
    base_path: Path,
    split_name: str,
    class_map: dict
) -> None:
    """
    Baca _annotations.csv di folder split, lalu buat mask .png untuk
    setiap gambar. Setiap bounding-box digambar sebagai persegi penuh
    pada mask dengan nilai piksel = class_id.

    Args:
        base_path  : Path root dataset (Ompreng-MBG-Fix-2)
        split_name : 'train' | 'valid' | 'test'
        class_map  : {class_id (int): class_name (str)}
    """
    img_dir  = base_path / split_name
    mask_dir = base_path / f"{split_name}_masks"
    csv_path = img_dir / "_annotations.csv"

    if not csv_path.exists():
        print(f"[Skip] CSV tidak ditemukan: {csv_path}")
        return

    existing = list(mask_dir.glob('*.png'))
    if existing:
        print(f"[Skip] Mask sudah ada di {mask_dir} ({len(existing)} file)")
        return

    mask_dir.mkdir(parents=True, exist_ok=True)

    # Reverse map: nama kelas (lower) → class_id
    name_to_id = {v.lower(): k for k, v in class_map.items() if k != 0}

    df      = pd.read_csv(csv_path)
    grouped = df.groupby('filename')
    print(f"Memproses {len(grouped)} gambar di split '{split_name}'...")

    for filename, group in tqdm(grouped):
        mask = np.zeros((IMG_HEIGHT, IMG_WIDTH), dtype=np.uint8)

        for _, row in group.iterrows():
            class_name = str(row['class']).strip().lower()
            class_id   = name_to_id.get(class_name, 0)
            if class_id == 0:
                continue

            # Normalisasi koordinat ke resolusi mask
            x1 = int(row['xmin'] * IMG_WIDTH  / row['width'])
            y1 = int(row['ymin'] * IMG_HEIGHT / row['height'])
            x2 = int(row['xmax'] * IMG_WIDTH  / row['width'])
            y2 = int(row['ymax'] * IMG_HEIGHT / row['height'])

            cv2.rectangle(mask, (x1, y1), (x2, y2), int(class_id), -1)

        mask_path = mask_dir / f"{Path(filename).stem}.png"
        cv2.imwrite(str(mask_path), mask)

    print(f"✓ {len(grouped)} mask tersimpan di {mask_dir}")


# Jalankan untuk ketiga split
for split in ['train', 'valid', 'test']:
    generate_masks_from_csv(BASE_DIR, split, CLASS_MAPPING)

print("\nKonversi mask dari CSV selesai.")
# Out:
# Memproses 1296 gambar di split 'train'...
# 100%|██████████| 1296/1296 [00:01<00:00, 874.45it/s]
# ✓ 1296 mask tersimpan di Ompreng-MBG-Fix-2/train_masks
# Memproses 54 gambar di split 'valid'...
# 100%|██████████| 54/54 [00:00<00:00, 1023.09it/s]
# ✓ 54 mask tersimpan di Ompreng-MBG-Fix-2/valid_masks
# Memproses 54 gambar di split 'test'...
# 100%|██████████| 54/54 [00:00<00:00, 956.29it/s]
# ✓ 54 mask tersimpan di Ompreng-MBG-Fix-2/test_masks
#
# Konversi mask dari CSV selesai.

# %%
# Visualisasi Sampel Dataset
def visualize_sample(img_path, mask_path, class_mapping, class_colors):
    img    = cv2.cvtColor(cv2.imread(str(img_path)), cv2.COLOR_BGR2RGB)
    mask   = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)

    colored = np.zeros((*mask.shape, 3), dtype=np.uint8)
    for cls_id, color in class_colors.items():
        colored[mask == cls_id] = color

    fig, axes = plt.subplots(1, 3, figsize=(14, 4))
    axes[0].imshow(img);                 axes[0].set_title('📷 Gambar Ompreng',  fontsize=13, fontweight='bold')
    axes[1].imshow(mask, cmap='tab10');  axes[1].set_title('🎭 Mask (Raw)',       fontsize=13, fontweight='bold')
    axes[2].imshow(colored);            axes[2].set_title('🎨 Mask Berwarna',    fontsize=13, fontweight='bold')

    patches = [mpatches.Patch(color=np.array(c)/255, label=class_mapping[i])
               for i, c in class_colors.items() if i > 0]
    axes[2].legend(handles=patches, loc='lower right', fontsize=8)
    for ax in axes: ax.axis('off')

    plt.suptitle('Contoh Sampel Dataset Ompreng MBG (Roboflow)',
                 fontsize=15, fontweight='bold', y=1.02)
    plt.tight_layout()
    plt.show()

# Tampilkan 3 sampel acak dari train split
img_paths  = sorted(IMAGES_TRAIN.glob('*.[jp][pn]g'))
mask_paths = sorted(MASKS_TRAIN.glob('*.png'))
n_sample   = min(3, len(img_paths))

for i in random.sample(range(min(len(img_paths), len(mask_paths))), n_sample):
    visualize_sample(img_paths[i], mask_paths[i], CLASS_MAPPING, CLASS_COLORS)
# Out:
# Glyph 128247 (\N{CAMERA}) missing from font(s) DejaVu Sans.
# Glyph 127917 (\N{PERFORMING ARTS}) missing from font(s) DejaVu Sans.
# Glyph 127912 (\N{ARTIST PALETTE}) missing from font(s) DejaVu Sans.
# Glyph 128247 (\N{CAMERA}) missing from font(s) DejaVu Sans.
# Glyph 127917 (\N{PERFORMING ARTS}) missing from font(s) DejaVu Sans.
# Glyph 127912 (\N{ARTIST PALETTE}) missing from font(s) DejaVu Sans.

# %% [markdown]
# ## Data Pipeline

# %%
# Load & preprocess gambar dan mask
def load_image_mask(img_path: str, mask_path: str):
    # Load gambar — support jpg & png
    raw = tf.io.read_file(img_path)
    img = tf.image.decode_image(raw, channels=3, expand_animations=False)
    img = tf.image.resize(img, [IMG_HEIGHT, IMG_WIDTH])
    img = tf.cast(img, tf.float32) / 255.0

    # Load mask
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH],
                           method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    mask = tf.cast(mask, tf.int32)
    mask = tf.squeeze(mask, axis=-1)

    # Clip nilai class agar tidak melebihi NUM_CLASSES
    mask = tf.clip_by_value(mask, 0, NUM_CLASSES - 1)

    # One-hot encoding
    mask_onehot = tf.one_hot(mask, NUM_CLASSES)
    return img, mask_onehot


# Augmentasi data on-the-fly
@tf.function
def augment(img, mask):
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    img = tf.image.random_brightness(img, 0.15)
    img = tf.image.random_contrast(img, 0.85, 1.15)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, mask


# Membuat tf.data.Dataset dari dua folder (images + masks)
def build_dataset(img_dir: Path, mask_dir: Path,
                  augment_data: bool = False,
                  batch_size: int = BATCH_SIZE) -> tf.data.Dataset:
    img_paths  = sorted(img_dir.glob('*.[jp][pn]g'))
    mask_paths = sorted(mask_dir.glob('*.png'))

    # Pastikan jumlah sama (stem yang cocok)
    img_stems  = {p.stem: p for p in img_paths}
    mask_stems = {p.stem: p for p in mask_paths}
    common     = sorted(set(img_stems) & set(mask_stems))

    matched_imgs  = [str(img_stems[s])  for s in common]
    matched_masks = [str(mask_stems[s]) for s in common]

    print(f"  {img_dir.name}: {len(common)} pasang gambar-mask")

    ds = tf.data.Dataset.from_tensor_slices((matched_imgs, matched_masks))
    ds = ds.map(load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds


# Build dataset dari split Roboflow
print("Membangun dataset...")
train_ds = build_dataset(IMAGES_TRAIN, MASKS_TRAIN, augment_data=True)
val_ds   = build_dataset(IMAGES_VAL,   MASKS_VAL,   augment_data=False)
test_ds  = build_dataset(IMAGES_TEST,  MASKS_TEST,  augment_data=False)

print(f'\nTrain : {len(train_ds)} batch')
print(f'Val   : {len(val_ds)} batch')
print(f'Test  : {len(test_ds)} batch')

# Verifikasi shape
for x, y in train_ds.take(1):
    print(f'\nShape input : {x.shape}  (B, H, W, C)')
    print(f'Shape mask  : {y.shape}  (B, H, W, num_classes)')
# Out:
# Membangun dataset...
#   train: 1296 pasang gambar-mask
#   valid: 54 pasang gambar-mask
#   test: 54 pasang gambar-mask
#
# Train : 162 batch
# Val   : 7 batch
# Test  : 7 batch
#
# Shape input : (8, 256, 256, 3)  (B, H, W, C)
# Shape mask  : (8, 256, 256, 6)  (B, H, W, num_classes)

# %% [markdown]
# ## Arsitektur Model

# %%
# Custom Layer: Attention Gate
class AttentionGate(layers.Layer):
    def __init__(self, filters: int, name: str = 'attention_gate', **kwargs):
        super().__init__(name=name, **kwargs)
        self.filters = filters
        self.W_g     = layers.Conv2D(filters, 1, use_bias=False, padding='same')
        self.bn_g    = layers.BatchNormalization()
        self.W_x     = layers.Conv2D(filters, 1, use_bias=False, padding='same')
        self.bn_x    = layers.BatchNormalization()
        self.psi     = layers.Conv2D(1, 1, use_bias=False, padding='same')
        self.bn_psi  = layers.BatchNormalization()

    def call(self, x, g, training=False):
        g_resized = tf.image.resize(g, tf.shape(x)[1:3], method='bilinear')
        g_proc    = self.bn_g(self.W_g(g_resized), training=training)
        x_proc    = self.bn_x(self.W_x(x),         training=training)
        combined  = tf.nn.relu(g_proc + x_proc)
        alpha     = tf.nn.sigmoid(self.bn_psi(self.psi(combined), training=training))
        return x * alpha

    def get_config(self):
        cfg = super().get_config()
        cfg.update({'filters': self.filters})
        return cfg


# Custom Layer: ConvBnRelu
class ConvBnRelu(layers.Layer):
    def __init__(self, filters: int, kernel_size: int = 3,
                 name: str = 'conv_bn_relu', **kwargs):
        super().__init__(name=name, **kwargs)
        self.filters     = filters
        self.kernel_size = kernel_size
        self.conv = layers.Conv2D(filters, kernel_size, padding='same',
                                  kernel_initializer='he_normal', use_bias=False)
        self.bn   = layers.BatchNormalization()
        self.relu = layers.Activation('relu')

    def call(self, x, training=False):
        return self.relu(self.bn(self.conv(x), training=training))

    def get_config(self):
        cfg = super().get_config()
        cfg.update({'filters': self.filters, 'kernel_size': self.kernel_size})
        return cfg

# %%
# Decoder block U-Net dengan Attention Gate
def build_decoder_block(x, skip_feat, g_signal, filters: int, block_name: str):
    x             = layers.UpSampling2D(size=(2, 2), name=f'{block_name}_upsample')(x)
    attn          = AttentionGate(filters // 2, name=f'{block_name}_attn')
    skip_attended = attn(skip_feat, g_signal)
    x             = layers.Concatenate(name=f'{block_name}_concat')([x, skip_attended])
    x             = ConvBnRelu(filters, name=f'{block_name}_conv1')(x)
    x             = ConvBnRelu(filters, name=f'{block_name}_conv2')(x)
    return x


# U-Net + MobileNetV2 Backbone
def build_unet_mobilenetv2(
    input_shape    = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS),
    num_classes    = NUM_CLASSES,
    decoder_filters = (256, 128, 64, 32)
):
    inputs    = keras.Input(shape=input_shape, name='input_image')
    mobilenet = MobileNetV2(input_tensor=inputs, include_top=False,
                             weights='imagenet', alpha=1.0)
    mobilenet.trainable = True

    skip_names = [
        'block_1_expand_relu',    # 128×128
        'block_3_expand_relu',    # 64×64
        'block_6_expand_relu',    # 32×32
        'block_13_expand_relu',   # 16×16
    ]
    skips      = [mobilenet.get_layer(n).output for n in skip_names]
    bottleneck = mobilenet.get_layer('block_16_project').output

    # Bridge
    bridge = ConvBnRelu(512, name='bridge_conv1')(bottleneck)
    bridge = ConvBnRelu(512, name='bridge_conv2')(bridge)

    # Decoder
    x = bridge
    for i, (skip, f) in enumerate(zip(reversed(skips), decoder_filters)):
        x = build_decoder_block(x, skip, bridge if i == 0 else x,
                                 f, f'dec{i+1}')

    x = layers.UpSampling2D(size=(2, 2), name='final_upsample')(x)
    x = ConvBnRelu(16, name='head_conv')(x)
    outputs = layers.Conv2D(
        num_classes, 1, activation='softmax',
        padding='same', name='segmentation_output'
    )(x)

    return Model(inputs=inputs, outputs=outputs, name='UNet_MobileNetV2_MBG')


model = build_unet_mobilenetv2()
print(f'Total parameter : {model.count_params():,}')
print(f'Output shape    : {model.output_shape}')
model.summary(line_length=100, expand_nested=False)
# Out:
# `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Total parameter : 9,878,886
# Output shape    : (None, 256, 256, 6)
# Model: "UNet_MobileNetV2_MBG"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape            ┃        Param # ┃ Connected to            ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)    │ (None, 256, 256, 3)     │              0 │ -                       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ Conv1 (Conv2D)              │ (None, 128, 128, 32)    │            864 │ input_image[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ bn_Conv1                    │ (None, 128, 128, 32)    │            128 │ Conv1[0][0]             │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ Conv1_relu (ReLU)           │ (None, 128, 128, 32)    │              0 │ bn_Conv1[0][0]          │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ expanded_conv_depthwise     │ (None, 128, 128, 32)    │            288 │ Conv1_relu[0][0]        │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ expanded_conv_depthwise_BN  │ (None, 128, 128, 32)    │            128 │ expanded_conv_depthwis… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ expanded_conv_depthwise_re… │ (None, 128, 128, 32)    │              0 │ expanded_conv_depthwis… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ expanded_conv_project       │ (None, 128, 128, 16)    │            512 │ expanded_conv_depthwis… │
# │ (Conv2D)                    │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ expanded_conv_project_BN    │ (None, 128, 128, 16)    │             64 │ expanded_conv_project[… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_1_expand (Conv2D)     │ (None, 128, 128, 96)    │          1,536 │ expanded_conv_project_… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_1_expand_BN           │ (None, 128, 128, 96)    │            384 │ block_1_expand[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_1_expand_relu (ReLU)  │ (None, 128, 128, 96)    │              0 │ block_1_expand_BN[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_1_pad (ZeroPadding2D) │ (None, 129, 129, 96)    │              0 │ block_1_expand_relu[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_1_depthwise           │ (None, 64, 64, 96)      │            864 │ block_1_pad[0][0]       │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_1_depthwise_BN        │ (None, 64, 64, 96)      │            384 │ block_1_depthwise[0][0] │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_1_depthwise_relu      │ (None, 64, 64, 96)      │              0 │ block_1_depthwise_BN[0… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_1_project (Conv2D)    │ (None, 64, 64, 24)      │          2,304 │ block_1_depthwise_relu… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_1_project_BN          │ (None, 64, 64, 24)      │             96 │ block_1_project[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_2_expand (Conv2D)     │ (None, 64, 64, 144)     │          3,456 │ block_1_project_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_2_expand_BN           │ (None, 64, 64, 144)     │            576 │ block_2_expand[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_2_expand_relu (ReLU)  │ (None, 64, 64, 144)     │              0 │ block_2_expand_BN[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_2_depthwise           │ (None, 64, 64, 144)     │          1,296 │ block_2_expand_relu[0]… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_2_depthwise_BN        │ (None, 64, 64, 144)     │            576 │ block_2_depthwise[0][0] │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_2_depthwise_relu      │ (None, 64, 64, 144)     │              0 │ block_2_depthwise_BN[0… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_2_project (Conv2D)    │ (None, 64, 64, 24)      │          3,456 │ block_2_depthwise_relu… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_2_project_BN          │ (None, 64, 64, 24)      │             96 │ block_2_project[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_2_add (Add)           │ (None, 64, 64, 24)      │              0 │ block_1_project_BN[0][… │
# │                             │                         │                │ block_2_project_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_3_expand (Conv2D)     │ (None, 64, 64, 144)     │          3,456 │ block_2_add[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_3_expand_BN           │ (None, 64, 64, 144)     │            576 │ block_3_expand[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_3_expand_relu (ReLU)  │ (None, 64, 64, 144)     │              0 │ block_3_expand_BN[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_3_pad (ZeroPadding2D) │ (None, 65, 65, 144)     │              0 │ block_3_expand_relu[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_3_depthwise           │ (None, 32, 32, 144)     │          1,296 │ block_3_pad[0][0]       │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_3_depthwise_BN        │ (None, 32, 32, 144)     │            576 │ block_3_depthwise[0][0] │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_3_depthwise_relu      │ (None, 32, 32, 144)     │              0 │ block_3_depthwise_BN[0… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_3_project (Conv2D)    │ (None, 32, 32, 32)      │          4,608 │ block_3_depthwise_relu… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_3_project_BN          │ (None, 32, 32, 32)      │            128 │ block_3_project[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_4_expand (Conv2D)     │ (None, 32, 32, 192)     │          6,144 │ block_3_project_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_4_expand_BN           │ (None, 32, 32, 192)     │            768 │ block_4_expand[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_4_expand_relu (ReLU)  │ (None, 32, 32, 192)     │              0 │ block_4_expand_BN[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_4_depthwise           │ (None, 32, 32, 192)     │          1,728 │ block_4_expand_relu[0]… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_4_depthwise_BN        │ (None, 32, 32, 192)     │            768 │ block_4_depthwise[0][0] │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_4_depthwise_relu      │ (None, 32, 32, 192)     │              0 │ block_4_depthwise_BN[0… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_4_project (Conv2D)    │ (None, 32, 32, 32)      │          6,144 │ block_4_depthwise_relu… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_4_project_BN          │ (None, 32, 32, 32)      │            128 │ block_4_project[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_4_add (Add)           │ (None, 32, 32, 32)      │              0 │ block_3_project_BN[0][… │
# │                             │                         │                │ block_4_project_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_5_expand (Conv2D)     │ (None, 32, 32, 192)     │          6,144 │ block_4_add[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_5_expand_BN           │ (None, 32, 32, 192)     │            768 │ block_5_expand[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_5_expand_relu (ReLU)  │ (None, 32, 32, 192)     │              0 │ block_5_expand_BN[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_5_depthwise           │ (None, 32, 32, 192)     │          1,728 │ block_5_expand_relu[0]… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_5_depthwise_BN        │ (None, 32, 32, 192)     │            768 │ block_5_depthwise[0][0] │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_5_depthwise_relu      │ (None, 32, 32, 192)     │              0 │ block_5_depthwise_BN[0… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_5_project (Conv2D)    │ (None, 32, 32, 32)      │          6,144 │ block_5_depthwise_relu… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_5_project_BN          │ (None, 32, 32, 32)      │            128 │ block_5_project[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_5_add (Add)           │ (None, 32, 32, 32)      │              0 │ block_4_add[0][0],      │
# │                             │                         │                │ block_5_project_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_6_expand (Conv2D)     │ (None, 32, 32, 192)     │          6,144 │ block_5_add[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_6_expand_BN           │ (None, 32, 32, 192)     │            768 │ block_6_expand[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_6_expand_relu (ReLU)  │ (None, 32, 32, 192)     │              0 │ block_6_expand_BN[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_6_pad (ZeroPadding2D) │ (None, 33, 33, 192)     │              0 │ block_6_expand_relu[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_6_depthwise           │ (None, 16, 16, 192)     │          1,728 │ block_6_pad[0][0]       │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_6_depthwise_BN        │ (None, 16, 16, 192)     │            768 │ block_6_depthwise[0][0] │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_6_depthwise_relu      │ (None, 16, 16, 192)     │              0 │ block_6_depthwise_BN[0… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_6_project (Conv2D)    │ (None, 16, 16, 64)      │         12,288 │ block_6_depthwise_relu… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_6_project_BN          │ (None, 16, 16, 64)      │            256 │ block_6_project[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_7_expand (Conv2D)     │ (None, 16, 16, 384)     │         24,576 │ block_6_project_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_7_expand_BN           │ (None, 16, 16, 384)     │          1,536 │ block_7_expand[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_7_expand_relu (ReLU)  │ (None, 16, 16, 384)     │              0 │ block_7_expand_BN[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_7_depthwise           │ (None, 16, 16, 384)     │          3,456 │ block_7_expand_relu[0]… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_7_depthwise_BN        │ (None, 16, 16, 384)     │          1,536 │ block_7_depthwise[0][0] │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_7_depthwise_relu      │ (None, 16, 16, 384)     │              0 │ block_7_depthwise_BN[0… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_7_project (Conv2D)    │ (None, 16, 16, 64)      │         24,576 │ block_7_depthwise_relu… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_7_project_BN          │ (None, 16, 16, 64)      │            256 │ block_7_project[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_7_add (Add)           │ (None, 16, 16, 64)      │              0 │ block_6_project_BN[0][… │
# │                             │                         │                │ block_7_project_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_8_expand (Conv2D)     │ (None, 16, 16, 384)     │         24,576 │ block_7_add[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_8_expand_BN           │ (None, 16, 16, 384)     │          1,536 │ block_8_expand[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_8_expand_relu (ReLU)  │ (None, 16, 16, 384)     │              0 │ block_8_expand_BN[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_8_depthwise           │ (None, 16, 16, 384)     │          3,456 │ block_8_expand_relu[0]… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_8_depthwise_BN        │ (None, 16, 16, 384)     │          1,536 │ block_8_depthwise[0][0] │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_8_depthwise_relu      │ (None, 16, 16, 384)     │              0 │ block_8_depthwise_BN[0… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_8_project (Conv2D)    │ (None, 16, 16, 64)      │         24,576 │ block_8_depthwise_relu… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_8_project_BN          │ (None, 16, 16, 64)      │            256 │ block_8_project[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_8_add (Add)           │ (None, 16, 16, 64)      │              0 │ block_7_add[0][0],      │
# │                             │                         │                │ block_8_project_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_9_expand (Conv2D)     │ (None, 16, 16, 384)     │         24,576 │ block_8_add[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_9_expand_BN           │ (None, 16, 16, 384)     │          1,536 │ block_9_expand[0][0]    │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_9_expand_relu (ReLU)  │ (None, 16, 16, 384)     │              0 │ block_9_expand_BN[0][0] │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_9_depthwise           │ (None, 16, 16, 384)     │          3,456 │ block_9_expand_relu[0]… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_9_depthwise_BN        │ (None, 16, 16, 384)     │          1,536 │ block_9_depthwise[0][0] │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_9_depthwise_relu      │ (None, 16, 16, 384)     │              0 │ block_9_depthwise_BN[0… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_9_project (Conv2D)    │ (None, 16, 16, 64)      │         24,576 │ block_9_depthwise_relu… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_9_project_BN          │ (None, 16, 16, 64)      │            256 │ block_9_project[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_9_add (Add)           │ (None, 16, 16, 64)      │              0 │ block_8_add[0][0],      │
# │                             │                         │                │ block_9_project_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_10_expand (Conv2D)    │ (None, 16, 16, 384)     │         24,576 │ block_9_add[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_10_expand_BN          │ (None, 16, 16, 384)     │          1,536 │ block_10_expand[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_10_expand_relu (ReLU) │ (None, 16, 16, 384)     │              0 │ block_10_expand_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_10_depthwise          │ (None, 16, 16, 384)     │          3,456 │ block_10_expand_relu[0… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_10_depthwise_BN       │ (None, 16, 16, 384)     │          1,536 │ block_10_depthwise[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_10_depthwise_relu     │ (None, 16, 16, 384)     │              0 │ block_10_depthwise_BN[… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_10_project (Conv2D)   │ (None, 16, 16, 96)      │         36,864 │ block_10_depthwise_rel… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_10_project_BN         │ (None, 16, 16, 96)      │            384 │ block_10_project[0][0]  │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_11_expand (Conv2D)    │ (None, 16, 16, 576)     │         55,296 │ block_10_project_BN[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_11_expand_BN          │ (None, 16, 16, 576)     │          2,304 │ block_11_expand[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_11_expand_relu (ReLU) │ (None, 16, 16, 576)     │              0 │ block_11_expand_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_11_depthwise          │ (None, 16, 16, 576)     │          5,184 │ block_11_expand_relu[0… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_11_depthwise_BN       │ (None, 16, 16, 576)     │          2,304 │ block_11_depthwise[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_11_depthwise_relu     │ (None, 16, 16, 576)     │              0 │ block_11_depthwise_BN[… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_11_project (Conv2D)   │ (None, 16, 16, 96)      │         55,296 │ block_11_depthwise_rel… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_11_project_BN         │ (None, 16, 16, 96)      │            384 │ block_11_project[0][0]  │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_11_add (Add)          │ (None, 16, 16, 96)      │              0 │ block_10_project_BN[0]… │
# │                             │                         │                │ block_11_project_BN[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_12_expand (Conv2D)    │ (None, 16, 16, 576)     │         55,296 │ block_11_add[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_12_expand_BN          │ (None, 16, 16, 576)     │          2,304 │ block_12_expand[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_12_expand_relu (ReLU) │ (None, 16, 16, 576)     │              0 │ block_12_expand_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_12_depthwise          │ (None, 16, 16, 576)     │          5,184 │ block_12_expand_relu[0… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_12_depthwise_BN       │ (None, 16, 16, 576)     │          2,304 │ block_12_depthwise[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_12_depthwise_relu     │ (None, 16, 16, 576)     │              0 │ block_12_depthwise_BN[… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_12_project (Conv2D)   │ (None, 16, 16, 96)      │         55,296 │ block_12_depthwise_rel… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_12_project_BN         │ (None, 16, 16, 96)      │            384 │ block_12_project[0][0]  │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_12_add (Add)          │ (None, 16, 16, 96)      │              0 │ block_11_add[0][0],     │
# │                             │                         │                │ block_12_project_BN[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_13_expand (Conv2D)    │ (None, 16, 16, 576)     │         55,296 │ block_12_add[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_13_expand_BN          │ (None, 16, 16, 576)     │          2,304 │ block_13_expand[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_13_expand_relu (ReLU) │ (None, 16, 16, 576)     │              0 │ block_13_expand_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_13_pad                │ (None, 17, 17, 576)     │              0 │ block_13_expand_relu[0… │
# │ (ZeroPadding2D)             │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_13_depthwise          │ (None, 8, 8, 576)       │          5,184 │ block_13_pad[0][0]      │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_13_depthwise_BN       │ (None, 8, 8, 576)       │          2,304 │ block_13_depthwise[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_13_depthwise_relu     │ (None, 8, 8, 576)       │              0 │ block_13_depthwise_BN[… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_13_project (Conv2D)   │ (None, 8, 8, 160)       │         92,160 │ block_13_depthwise_rel… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_13_project_BN         │ (None, 8, 8, 160)       │            640 │ block_13_project[0][0]  │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_14_expand (Conv2D)    │ (None, 8, 8, 960)       │        153,600 │ block_13_project_BN[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_14_expand_BN          │ (None, 8, 8, 960)       │          3,840 │ block_14_expand[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_14_expand_relu (ReLU) │ (None, 8, 8, 960)       │              0 │ block_14_expand_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_14_depthwise          │ (None, 8, 8, 960)       │          8,640 │ block_14_expand_relu[0… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_14_depthwise_BN       │ (None, 8, 8, 960)       │          3,840 │ block_14_depthwise[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_14_depthwise_relu     │ (None, 8, 8, 960)       │              0 │ block_14_depthwise_BN[… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_14_project (Conv2D)   │ (None, 8, 8, 160)       │        153,600 │ block_14_depthwise_rel… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_14_project_BN         │ (None, 8, 8, 160)       │            640 │ block_14_project[0][0]  │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_14_add (Add)          │ (None, 8, 8, 160)       │              0 │ block_13_project_BN[0]… │
# │                             │                         │                │ block_14_project_BN[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_15_expand (Conv2D)    │ (None, 8, 8, 960)       │        153,600 │ block_14_add[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_15_expand_BN          │ (None, 8, 8, 960)       │          3,840 │ block_15_expand[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_15_expand_relu (ReLU) │ (None, 8, 8, 960)       │              0 │ block_15_expand_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_15_depthwise          │ (None, 8, 8, 960)       │          8,640 │ block_15_expand_relu[0… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_15_depthwise_BN       │ (None, 8, 8, 960)       │          3,840 │ block_15_depthwise[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_15_depthwise_relu     │ (None, 8, 8, 960)       │              0 │ block_15_depthwise_BN[… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_15_project (Conv2D)   │ (None, 8, 8, 160)       │        153,600 │ block_15_depthwise_rel… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_15_project_BN         │ (None, 8, 8, 160)       │            640 │ block_15_project[0][0]  │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_15_add (Add)          │ (None, 8, 8, 160)       │              0 │ block_14_add[0][0],     │
# │                             │                         │                │ block_15_project_BN[0]… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_16_expand (Conv2D)    │ (None, 8, 8, 960)       │        153,600 │ block_15_add[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_16_expand_BN          │ (None, 8, 8, 960)       │          3,840 │ block_16_expand[0][0]   │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_16_expand_relu (ReLU) │ (None, 8, 8, 960)       │              0 │ block_16_expand_BN[0][… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_16_depthwise          │ (None, 8, 8, 960)       │          8,640 │ block_16_expand_relu[0… │
# │ (DepthwiseConv2D)           │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_16_depthwise_BN       │ (None, 8, 8, 960)       │          3,840 │ block_16_depthwise[0][… │
# │ (BatchNormalization)        │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_16_depthwise_relu     │ (None, 8, 8, 960)       │              0 │ block_16_depthwise_BN[… │
# │ (ReLU)                      │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ block_16_project (Conv2D)   │ (None, 8, 8, 320)       │        307,200 │ block_16_depthwise_rel… │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ bridge_conv1 (ConvBnRelu)   │ (None, 8, 8, 512)       │      1,476,608 │ block_16_project[0][0]  │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ bridge_conv2 (ConvBnRelu)   │ (None, 8, 8, 512)       │      2,361,344 │ bridge_conv1[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec1_upsample               │ (None, 16, 16, 512)     │              0 │ bridge_conv2[0][0]      │
# │ (UpSampling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec1_attn (AttentionGate)   │ (None, 16, 16, 576)     │        140,420 │ block_13_expand_relu[0… │
# │                             │                         │                │ bridge_conv2[0][0]      │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec1_concat (Concatenate)   │ (None, 16, 16, 1088)    │              0 │ dec1_upsample[0][0],    │
# │                             │                         │                │ dec1_attn[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec1_conv1 (ConvBnRelu)     │ (None, 16, 16, 256)     │      2,507,776 │ dec1_concat[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec1_conv2 (ConvBnRelu)     │ (None, 16, 16, 256)     │        590,848 │ dec1_conv1[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec2_upsample               │ (None, 32, 32, 256)     │              0 │ dec1_conv2[0][0]        │
# │ (UpSampling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec2_attn (AttentionGate)   │ (None, 32, 32, 192)     │         29,252 │ block_6_expand_relu[0]… │
# │                             │                         │                │ dec1_conv2[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec2_concat (Concatenate)   │ (None, 32, 32, 448)     │              0 │ dec2_upsample[0][0],    │
# │                             │                         │                │ dec2_attn[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec2_conv1 (ConvBnRelu)     │ (None, 32, 32, 128)     │        516,608 │ dec2_concat[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec2_conv2 (ConvBnRelu)     │ (None, 32, 32, 128)     │        147,968 │ dec2_conv1[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec3_upsample               │ (None, 64, 64, 128)     │              0 │ dec2_conv2[0][0]        │
# │ (UpSampling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec3_attn (AttentionGate)   │ (None, 64, 64, 144)     │          8,996 │ block_3_expand_relu[0]… │
# │                             │                         │                │ dec2_conv2[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec3_concat (Concatenate)   │ (None, 64, 64, 272)     │              0 │ dec3_upsample[0][0],    │
# │                             │                         │                │ dec3_attn[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec3_conv1 (ConvBnRelu)     │ (None, 64, 64, 64)      │        156,928 │ dec3_concat[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec3_conv2 (ConvBnRelu)     │ (None, 64, 64, 64)      │         37,120 │ dec3_conv1[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec4_upsample               │ (None, 128, 128, 64)    │              0 │ dec3_conv2[0][0]        │
# │ (UpSampling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec4_attn (AttentionGate)   │ (None, 128, 128, 96)    │          2,708 │ block_1_expand_relu[0]… │
# │                             │                         │                │ dec3_conv2[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec4_concat (Concatenate)   │ (None, 128, 128, 160)   │              0 │ dec4_upsample[0][0],    │
# │                             │                         │                │ dec4_attn[0][0]         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec4_conv1 (ConvBnRelu)     │ (None, 128, 128, 32)    │         46,208 │ dec4_concat[0][0]       │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ dec4_conv2 (ConvBnRelu)     │ (None, 128, 128, 32)    │          9,344 │ dec4_conv1[0][0]        │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ final_upsample              │ (None, 256, 256, 32)    │              0 │ dec4_conv2[0][0]        │
# │ (UpSampling2D)              │                         │                │                         │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ head_conv (ConvBnRelu)      │ (None, 256, 256, 16)    │          4,672 │ final_upsample[0][0]    │
# ├─────────────────────────────┼─────────────────────────┼────────────────┼─────────────────────────┤
# │ segmentation_output         │ (None, 256, 256, 6)     │            102 │ head_conv[0][0]         │
# │ (Conv2D)                    │                         │                │                         │
# └─────────────────────────────┴─────────────────────────┴────────────────┴─────────────────────────┘
#  Total params: 9,878,886 (37.68 MB)
#  Trainable params: 9,843,006 (37.55 MB)
#  Non-trainable params: 35,880 (140.16 KB)

# %% [markdown]
# ## Custom Loss Function & Metrics

# %%
# Dice + Categorical Cross-Entropy Loss
class DiceBCELoss(keras.losses.Loss):
    def __init__(self, alpha: float = 0.5, smooth: float = 1e-6,
                 name: str = 'dice_bce_loss', **kwargs):
        super().__init__(name=name, **kwargs)
        self.alpha  = alpha
        self.smooth = smooth

    def dice_loss(self, y_true, y_pred):
        y_true_f     = tf.reshape(y_true, [-1, NUM_CLASSES])
        y_pred_f     = tf.reshape(y_pred, [-1, NUM_CLASSES])
        intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
        dice = (2. * intersection + self.smooth) / (
            tf.reduce_sum(y_true_f, axis=0) +
            tf.reduce_sum(y_pred_f, axis=0) + self.smooth
        )
        return 1. - tf.reduce_mean(dice[1:])   # skip background

    def call(self, y_true, y_pred):
        cce  = keras.losses.categorical_crossentropy(y_true, y_pred)
        dice = self.dice_loss(y_true, y_pred)
        return self.alpha * dice + (1. - self.alpha) * tf.reduce_mean(cce)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({'alpha': self.alpha, 'smooth': self.smooth})
        return cfg


# MeanIoU kompatibel dengan output softmax
class MeanIoU(tf.keras.metrics.MeanIoU):
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true_idx = tf.argmax(y_true, axis=-1)
        y_pred_idx = tf.argmax(y_pred, axis=-1)
        return super().update_state(y_true_idx, y_pred_idx, sample_weight)


# Inisialisasi
loss_fn          = DiceBCELoss(alpha=0.5)
optimizer        = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
iou_metric_train = MeanIoU(num_classes=NUM_CLASSES, name='train_miou')
iou_metric_val   = MeanIoU(num_classes=NUM_CLASSES, name='val_miou')

# %% [markdown]
# ## Custom Callback

# %%
class NutritionMetricsCallback(keras.callbacks.Callback):
    """Mencetak per-class accuracy & menyimpan model terbaik tiap epoch."""

    def __init__(self, val_dataset, class_mapping: dict,
                 save_path: str, patience: int = 10):
        super().__init__()
        self.val_dataset   = val_dataset
        self.class_mapping = class_mapping
        self.save_path     = save_path
        self.patience      = patience
        self.best_val_loss = np.inf
        self.wait          = 0
        self.stop_training = False
        self.history       = {'epoch': [], 'class_accuracy': []}

    def on_epoch_end(self, epoch, logs=None):
        logs          = logs or {}
        class_correct = np.zeros(NUM_CLASSES)
        class_total   = np.zeros(NUM_CLASSES)

        for x_batch, y_batch in self.val_dataset:
            preds    = self.model(x_batch, training=False)
            pred_cls = tf.argmax(preds,   axis=-1).numpy()
            true_cls = tf.argmax(y_batch, axis=-1).numpy()
            for c in range(NUM_CLASSES):
                mask_c           = true_cls == c
                class_total[c]   += mask_c.sum()
                class_correct[c] += (pred_cls[mask_c] == c).sum()

        acc_per_class = np.where(
            class_total > 0, class_correct / (class_total + 1e-8), 0.0
        )

        print(f'\n[Epoch {epoch+1}] Per-Class Accuracy:')
        for c, (name, acc) in enumerate(zip(self.class_mapping.values(), acc_per_class)):
            bar = '█' * int(acc * 20) + '░' * (20 - int(acc * 20))
            print(f'  {name:>12s} [{bar}] {acc*100:5.1f}%')

        self.history['epoch'].append(epoch + 1)
        self.history['class_accuracy'].append(acc_per_class.tolist())

        # Model Checkpoint (simpan jika val_loss membaik)
        val_loss = logs.get('val_loss', np.inf)
        if val_loss < self.best_val_loss:
            self.best_val_loss = val_loss
            self.wait          = 0
            self.model.save(self.save_path)
            print(f'  ✓ Model terbaik tersimpan → {self.save_path} (val_loss={val_loss:.4f})')
        else:
            self.wait += 1
            if self.wait >= self.patience:
                print(f'\n  Early stopping setelah {self.patience} epoch tanpa perbaikan.')
                self.stop_training = True

# %% [markdown]
# ## Custom Training Loop (tf.GradientTape)

# %%
# TensorBoard writers
Path(LOG_DIR).mkdir(parents=True, exist_ok=True)
train_writer = tf.summary.create_file_writer(LOG_DIR + '/train')
val_writer   = tf.summary.create_file_writer(LOG_DIR + '/val')
print(f'TensorBoard log dir: {LOG_DIR}')

@tf.function
def train_step(x_batch, y_batch):
    with tf.GradientTape() as tape:
        y_pred = model(x_batch, training=True)
        loss   = loss_fn(y_batch, y_pred)
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    iou_metric_train.update_state(y_batch, y_pred)
    return loss

@tf.function
def val_step(x_batch, y_batch):
    y_pred = model(x_batch, training=False)
    loss   = loss_fn(y_batch, y_pred)
    iou_metric_val.update_state(y_batch, y_pred)
    return loss

def cosine_decay_lr(epoch: int, total_epochs: int,
                    lr_init: float = LEARNING_RATE,
                    lr_min: float  = 1e-6) -> float:
    cosine = 0.5 * (1 + np.cos(np.pi * epoch / total_epochs))
    return lr_min + (lr_init - lr_min) * cosine

# Inisialisasi callback
nutrition_cb = NutritionMetricsCallback(
    val_dataset   = val_ds,
    class_mapping = CLASS_MAPPING,
    save_path     = MODEL_SAVE_PATH,
    patience      = 10
)
nutrition_cb.set_model(model)

# Main Training Loop
history = {'train_loss': [], 'val_loss': [], 'train_miou': [], 'val_miou': []}

print('='*65)
print('MEMULAI TRAINING')
print('='*65)

for epoch in range(EPOCHS):
    lr = cosine_decay_lr(epoch, EPOCHS)
    optimizer.learning_rate.assign(lr)

    iou_metric_train.reset_state()
    iou_metric_val.reset_state()

    # Training
    train_losses = [float(train_step(xb, yb)) for xb, yb in train_ds]

    # Validasi
    val_losses   = [float(val_step(xb, yb))   for xb, yb in val_ds]

    epoch_train_loss = np.mean(train_losses)
    epoch_val_loss   = np.mean(val_losses)
    epoch_train_miou = float(iou_metric_train.result())
    epoch_val_miou   = float(iou_metric_val.result())

    history['train_loss'].append(epoch_train_loss)
    history['val_loss'].append(epoch_val_loss)
    history['train_miou'].append(epoch_train_miou)
    history['val_miou'].append(epoch_val_miou)

    with train_writer.as_default():
        tf.summary.scalar('loss',          epoch_train_loss, step=epoch)
        tf.summary.scalar('mean_iou',      epoch_train_miou, step=epoch)
        tf.summary.scalar('learning_rate', lr,               step=epoch)
    with val_writer.as_default():
        tf.summary.scalar('loss',          epoch_val_loss,  step=epoch)
        tf.summary.scalar('mean_iou',      epoch_val_miou,  step=epoch)

    print(f'Epoch {epoch+1:3d}/{EPOCHS} | '
          f'Loss: {epoch_train_loss:.4f} | Val Loss: {epoch_val_loss:.4f} | '
          f'mIoU: {epoch_train_miou:.4f} | Val mIoU: {epoch_val_miou:.4f} | '
          f'LR: {lr:.2e}')

    logs = {'loss': epoch_train_loss, 'val_loss': epoch_val_loss,
            'mean_iou': epoch_train_miou, 'val_mean_iou': epoch_val_miou}
    nutrition_cb.on_epoch_end(epoch, logs=logs)
    if nutrition_cb.stop_training:
        break

train_writer.flush()
val_writer.flush()
# Out:
# TensorBoard log dir: logs/fit/20260522-110922
# =================================================================
# MEMULAI TRAINING
# =================================================================
# Epoch   1/50 | Loss: 1.0820 | Val Loss: 0.9797 | mIoU: 0.3702 | Val mIoU: 0.5252 | LR: 1.00e-04
#
# [Epoch 1] Per-Class Accuracy:
#     background [█████████████████░░░]  88.2%
#           buah [█████░░░░░░░░░░░░░░░]  25.5%
#    karbohidrat [██████████████░░░░░░]  71.5%
#        protein [██████████████░░░░░░]  73.0%
#          sayur [█████████████████░░░]  88.9%
#           susu [███████████████████░]  98.8%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.9797)
# Epoch   2/50 | Loss: 0.8307 | Val Loss: 0.8759 | mIoU: 0.6358 | Val mIoU: 0.6278 | LR: 9.99e-05
#
# [Epoch 2] Per-Class Accuracy:
#     background [███████████████████░]  96.9%
#           buah [████████░░░░░░░░░░░░]  43.1%
#    karbohidrat [████████████████░░░░]  80.0%
#        protein [█████████░░░░░░░░░░░]  45.2%
#          sayur [████████████████░░░░]  82.8%
#           susu [█████████████████░░░]  89.9%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.8759)
# Epoch   3/50 | Loss: 0.7094 | Val Loss: 0.8144 | mIoU: 0.7332 | Val mIoU: 0.5914 | LR: 9.96e-05
#
# [Epoch 3] Per-Class Accuracy:
#     background [███████████████████░]  97.5%
#           buah [█████░░░░░░░░░░░░░░░]  28.8%
#    karbohidrat [███████████████░░░░░]  77.8%
#        protein [███████░░░░░░░░░░░░░]  36.1%
#          sayur [████████████████░░░░]  80.6%
#           susu [██████████████████░░]  93.0%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.8144)
# Epoch   4/50 | Loss: 0.6287 | Val Loss: 0.6903 | mIoU: 0.7807 | Val mIoU: 0.6854 | LR: 9.91e-05
#
# [Epoch 4] Per-Class Accuracy:
#     background [███████████████████░]  95.9%
#           buah [███████████░░░░░░░░░]  58.8%
#    karbohidrat [█████████████████░░░]  89.6%
#        protein [███████████░░░░░░░░░]  55.1%
#          sayur [████████████████░░░░]  80.3%
#           susu [███████████████████░]  97.1%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.6903)
# Epoch   5/50 | Loss: 0.5632 | Val Loss: 0.6529 | mIoU: 0.8059 | Val mIoU: 0.6839 | LR: 9.84e-05
#
# [Epoch 5] Per-Class Accuracy:
#     background [███████████████████░]  97.9%
#           buah [████████████░░░░░░░░]  63.9%
#    karbohidrat [████████████████░░░░]  82.9%
#        protein [████████░░░░░░░░░░░░]  43.0%
#          sayur [██████████████░░░░░░]  73.2%
#           susu [███████████████████░]  95.1%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.6529)
# Epoch   6/50 | Loss: 0.5026 | Val Loss: 0.5897 | mIoU: 0.8288 | Val mIoU: 0.6910 | LR: 9.76e-05
#
# [Epoch 6] Per-Class Accuracy:
#     background [███████████████████░]  95.2%
#           buah [██████████████░░░░░░]  74.5%
#    karbohidrat [█████████████████░░░]  86.9%
#        protein [██████████░░░░░░░░░░]  50.4%
#          sayur [█████████████████░░░]  88.4%
#           susu [███████████████████░]  98.9%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.5897)
# Epoch   7/50 | Loss: 0.4465 | Val Loss: 0.5424 | mIoU: 0.8521 | Val mIoU: 0.7197 | LR: 9.65e-05
#
# [Epoch 7] Per-Class Accuracy:
#     background [███████████████████░]  95.9%
#           buah [████████████░░░░░░░░]  64.5%
#    karbohidrat [████████████████░░░░]  83.4%
#        protein [█████████████░░░░░░░]  67.9%
#          sayur [█████████████████░░░]  89.6%
#           susu [███████████████████░]  97.6%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.5424)
# Epoch   8/50 | Loss: 0.3980 | Val Loss: 0.4875 | mIoU: 0.8669 | Val mIoU: 0.7393 | LR: 9.53e-05
#
# [Epoch 8] Per-Class Accuracy:
#     background [███████████████████░]  97.1%
#           buah [██████████████░░░░░░]  73.0%
#    karbohidrat [█████████████████░░░]  89.8%
#        protein [███████████░░░░░░░░░]  56.2%
#          sayur [█████████████████░░░]  85.6%
#           susu [███████████████████░]  95.4%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.4875)
# Epoch   9/50 | Loss: 0.3548 | Val Loss: 0.4564 | mIoU: 0.8789 | Val mIoU: 0.7367 | LR: 9.39e-05
#
# [Epoch 9] Per-Class Accuracy:
#     background [███████████████████░]  97.6%
#           buah [███████████████░░░░░]  76.2%
#    karbohidrat [█████████████████░░░]  85.6%
#        protein [████████████░░░░░░░░]  60.2%
#          sayur [███████████████░░░░░]  79.8%
#           susu [██████████████████░░]  91.4%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.4564)
# Epoch  10/50 | Loss: 0.3170 | Val Loss: 0.4121 | mIoU: 0.8880 | Val mIoU: 0.7517 | LR: 9.23e-05
#
# [Epoch 10] Per-Class Accuracy:
#     background [███████████████████░]  96.5%
#           buah [██████████████░░░░░░]  70.6%
#    karbohidrat [█████████████████░░░]  87.2%
#        protein [██████████████░░░░░░]  74.1%
#          sayur [████████████████░░░░]  84.4%
#           susu [███████████████████░]  95.1%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.4121)
# Epoch  11/50 | Loss: 0.2834 | Val Loss: 0.3893 | mIoU: 0.8948 | Val mIoU: 0.7542 | LR: 9.05e-05
#
# [Epoch 11] Per-Class Accuracy:
#     background [███████████████████░]  97.5%
#           buah [██████████████░░░░░░]  70.7%
#    karbohidrat [████████████████░░░░]  84.7%
#        protein [██████████████░░░░░░]  74.5%
#          sayur [███████████████░░░░░]  79.5%
#           susu [█████████████████░░░]  89.1%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.3893)
# Epoch  12/50 | Loss: 0.2545 | Val Loss: 0.3662 | mIoU: 0.9011 | Val mIoU: 0.7535 | LR: 8.86e-05
#
# [Epoch 12] Per-Class Accuracy:
#     background [███████████████████░]  96.9%
#           buah [█████████████░░░░░░░]  68.8%
#    karbohidrat [█████████████████░░░]  89.2%
#        protein [██████████████░░░░░░]  71.2%
#          sayur [████████████████░░░░]  84.0%
#           susu [██████████████████░░]  92.7%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.3662)
# Epoch  13/50 | Loss: 0.2305 | Val Loss: 0.3662 | mIoU: 0.9049 | Val mIoU: 0.7387 | LR: 8.66e-05
#
# [Epoch 13] Per-Class Accuracy:
#     background [███████████████████░]  96.4%
#           buah [████████████░░░░░░░░]  64.3%
#    karbohidrat [█████████████████░░░]  87.2%
#        protein [██████████████░░░░░░]  71.6%
#          sayur [█████████████████░░░]  88.3%
#           susu [██████████████████░░]  93.6%
# Epoch  14/50 | Loss: 0.2103 | Val Loss: 0.3304 | mIoU: 0.9099 | Val mIoU: 0.7513 | LR: 8.44e-05
#
# [Epoch 14] Per-Class Accuracy:
#     background [███████████████████░]  97.2%
#           buah [██████████████░░░░░░]  71.9%
#    karbohidrat [█████████████████░░░]  85.7%
#        protein [██████████████░░░░░░]  74.2%
#          sayur [███████████████░░░░░]  78.8%
#           susu [███████████████████░]  95.4%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.3304)
# Epoch  15/50 | Loss: 0.1947 | Val Loss: 0.3471 | mIoU: 0.9104 | Val mIoU: 0.7191 | LR: 8.21e-05
#
# [Epoch 15] Per-Class Accuracy:
#     background [███████████████████░]  96.0%
#           buah [█████████████░░░░░░░]  66.3%
#    karbohidrat [█████████████████░░░]  87.6%
#        protein [████████████░░░░░░░░]  63.1%
#          sayur [█████████████████░░░]  88.1%
#           susu [███████████████████░]  97.7%
# Epoch  16/50 | Loss: 0.1796 | Val Loss: 0.3098 | mIoU: 0.9158 | Val mIoU: 0.7511 | LR: 7.96e-05
#
# [Epoch 16] Per-Class Accuracy:
#     background [██████████████████░░]  92.2%
#           buah [████████████████░░░░]  83.8%
#    karbohidrat [███████████████████░]  96.1%
#        protein [███████████████░░░░░]  77.3%
#          sayur [██████████████████░░]  92.7%
#           susu [███████████████████░]  99.7%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.3098)
# Epoch  17/50 | Loss: 0.1666 | Val Loss: 0.3333 | mIoU: 0.9201 | Val mIoU: 0.7198 | LR: 7.70e-05
#
# [Epoch 17] Per-Class Accuracy:
#     background [██████████████████░░]  92.8%
#           buah [██████████████░░░░░░]  70.6%
#    karbohidrat [██████████████████░░]  91.8%
#        protein [██████████████░░░░░░]  71.4%
#          sayur [███████████████████░]  96.7%
#           susu [███████████████████░]  99.8%
# Epoch  18/50 | Loss: 0.1555 | Val Loss: 0.3232 | mIoU: 0.9245 | Val mIoU: 0.7269 | LR: 7.43e-05
#
# [Epoch 18] Per-Class Accuracy:
#     background [██████████████████░░]  93.5%
#           buah [██████████████░░░░░░]  70.9%
#    karbohidrat [██████████████████░░]  90.2%
#        protein [███████████████░░░░░]  77.0%
#          sayur [██████████████████░░]  94.4%
#           susu [███████████████████░] 100.0%
# Epoch  19/50 | Loss: 0.1468 | Val Loss: 0.2723 | mIoU: 0.9263 | Val mIoU: 0.7699 | LR: 7.16e-05
#
# [Epoch 19] Per-Class Accuracy:
#     background [███████████████████░]  95.6%
#           buah [███████████████░░░░░]  76.0%
#    karbohidrat [█████████████████░░░]  89.2%
#        protein [███████████████░░░░░]  79.5%
#          sayur [█████████████████░░░]  86.8%
#           susu [███████████████████░]  99.0%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.2723)
# Epoch  20/50 | Loss: 0.1387 | Val Loss: 0.2715 | mIoU: 0.9292 | Val mIoU: 0.7734 | LR: 6.87e-05
#
# [Epoch 20] Per-Class Accuracy:
#     background [███████████████████░]  97.5%
#           buah [██████████████░░░░░░]  71.6%
#    karbohidrat [█████████████████░░░]  85.8%
#        protein [███████████████░░░░░]  76.7%
#          sayur [████████████████░░░░]  82.4%
#           susu [██████████████████░░]  93.7%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.2715)
# Epoch  21/50 | Loss: 0.1333 | Val Loss: 0.2536 | mIoU: 0.9295 | Val mIoU: 0.7835 | LR: 6.58e-05
#
# [Epoch 21] Per-Class Accuracy:
#     background [███████████████████░]  96.9%
#           buah [██████████████░░░░░░]  72.6%
#    karbohidrat [██████████████████░░]  91.6%
#        protein [███████████████░░░░░]  77.0%
#          sayur [█████████████████░░░]  85.8%
#           susu [██████████████████░░]  93.9%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.2536)
# Epoch  22/50 | Loss: 0.1246 | Val Loss: 0.2700 | mIoU: 0.9343 | Val mIoU: 0.7633 | LR: 6.28e-05
#
# [Epoch 22] Per-Class Accuracy:
#     background [███████████████████░]  95.9%
#           buah [█████████████░░░░░░░]  65.7%
#    karbohidrat [██████████████████░░]  91.2%
#        protein [███████████████░░░░░]  77.6%
#          sayur [█████████████████░░░]  89.9%
#           susu [███████████████████░]  97.4%
# Epoch  23/50 | Loss: 0.1190 | Val Loss: 0.2627 | mIoU: 0.9367 | Val mIoU: 0.7693 | LR: 5.98e-05
#
# [Epoch 23] Per-Class Accuracy:
#     background [██████████████████░░]  94.2%
#           buah [███████████████░░░░░]  75.1%
#    karbohidrat [██████████████████░░]  94.4%
#        protein [████████████████░░░░]  81.4%
#          sayur [█████████████████░░░]  88.5%
#           susu [███████████████████░]  99.1%
# Epoch  24/50 | Loss: 0.1147 | Val Loss: 0.2448 | mIoU: 0.9386 | Val mIoU: 0.7840 | LR: 5.67e-05
#
# [Epoch 24] Per-Class Accuracy:
#     background [███████████████████░]  95.4%
#           buah [███████████████░░░░░]  77.1%
#    karbohidrat [██████████████████░░]  94.0%
#        protein [███████████████░░░░░]  79.9%
#          sayur [█████████████████░░░]  88.0%
#           susu [███████████████████░]  98.6%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.2448)
# Epoch  25/50 | Loss: 0.1136 | Val Loss: 0.2393 | mIoU: 0.9374 | Val mIoU: 0.7881 | LR: 5.36e-05
#
# [Epoch 25] Per-Class Accuracy:
#     background [███████████████████░]  96.0%
#           buah [███████████████░░░░░]  76.4%
#    karbohidrat [██████████████████░░]  93.7%
#        protein [███████████████░░░░░]  78.9%
#          sayur [█████████████████░░░]  86.8%
#           susu [███████████████████░]  96.6%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.2393)
# Epoch  26/50 | Loss: 0.1062 | Val Loss: 0.2343 | mIoU: 0.9433 | Val mIoU: 0.7947 | LR: 5.05e-05
#
# [Epoch 26] Per-Class Accuracy:
#     background [███████████████████░]  95.6%
#           buah [███████████████░░░░░]  79.7%
#    karbohidrat [██████████████████░░]  94.9%
#        protein [███████████████░░░░░]  78.1%
#          sayur [█████████████████░░░]  88.4%
#           susu [███████████████████░]  96.1%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.2343)
# Epoch  27/50 | Loss: 0.1012 | Val Loss: 0.2409 | mIoU: 0.9467 | Val mIoU: 0.7887 | LR: 4.74e-05
#
# [Epoch 27] Per-Class Accuracy:
#     background [███████████████████░]  95.2%
#           buah [███████████████░░░░░]  77.8%
#    karbohidrat [██████████████████░░]  93.4%
#        protein [████████████████░░░░]  81.5%
#          sayur [█████████████████░░░]  88.7%
#           susu [███████████████████░]  97.1%
# Epoch  28/50 | Loss: 0.0986 | Val Loss: 0.2427 | mIoU: 0.9478 | Val mIoU: 0.7846 | LR: 4.43e-05
#
# [Epoch 28] Per-Class Accuracy:
#     background [██████████████████░░]  94.6%
#           buah [████████████████░░░░]  80.2%
#    karbohidrat [██████████████████░░]  93.9%
#        protein [████████████████░░░░]  81.1%
#          sayur [█████████████████░░░]  88.5%
#           susu [███████████████████░]  97.9%
# Epoch  29/50 | Loss: 0.0976 | Val Loss: 0.2453 | mIoU: 0.9470 | Val mIoU: 0.7805 | LR: 4.12e-05
#
# [Epoch 29] Per-Class Accuracy:
#     background [██████████████████░░]  94.7%
#           buah [███████████████░░░░░]  79.3%
#    karbohidrat [██████████████████░░]  93.6%
#        protein [████████████████░░░░]  80.0%
#          sayur [█████████████████░░░]  89.5%
#           susu [███████████████████░]  97.9%
# Epoch  30/50 | Loss: 0.0957 | Val Loss: 0.2358 | mIoU: 0.9478 | Val mIoU: 0.7886 | LR: 3.82e-05
#
# [Epoch 30] Per-Class Accuracy:
#     background [███████████████████░]  95.3%
#           buah [████████████████░░░░]  81.0%
#    karbohidrat [██████████████████░░]  93.4%
#        protein [███████████████░░░░░]  78.2%
#          sayur [██████████████████░░]  90.2%
#           susu [███████████████████░]  97.3%
# Epoch  31/50 | Loss: 0.0911 | Val Loss: 0.2293 | mIoU: 0.9519 | Val mIoU: 0.7966 | LR: 3.52e-05
#
# [Epoch 31] Per-Class Accuracy:
#     background [███████████████████░]  95.7%
#           buah [███████████████░░░░░]  78.4%
#    karbohidrat [██████████████████░░]  92.8%
#        protein [████████████████░░░░]  83.9%
#          sayur [█████████████████░░░]  87.1%
#           susu [███████████████████░]  98.0%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.2293)
# Epoch  32/50 | Loss: 0.0872 | Val Loss: 0.2249 | mIoU: 0.9551 | Val mIoU: 0.7995 | LR: 3.23e-05
#
# [Epoch 32] Per-Class Accuracy:
#     background [███████████████████░]  96.5%
#           buah [███████████████░░░░░]  77.9%
#    karbohidrat [██████████████████░░]  92.3%
#        protein [████████████████░░░░]  82.0%
#          sayur [█████████████████░░░]  85.2%
#           susu [███████████████████░]  96.0%
#   ✓ Model terbaik tersimpan → models/unet_mbg.keras (val_loss=0.2249)
# Epoch  33/50 | Loss: 0.0832 | Val Loss: 0.2255 | mIoU: 0.9591 | Val mIoU: 0.7991 | LR: 2.94e-05
#
# [Epoch 33] Per-Class Accuracy:
#     background [███████████████████░]  96.3%
#           buah [███████████████░░░░░]  76.7%
#    karbohidrat [██████████████████░░]  92.3%
#        protein [████████████████░░░░]  84.3%
#          sayur [█████████████████░░░]  85.5%
#           susu [███████████████████░]  95.7%
# Epoch  34/50 | Loss: 0.0795 | Val Loss: 0.2269 | mIoU: 0.9626 | Val mIoU: 0.7971 | LR: 2.67e-05
#
# [Epoch 34] Per-Class Accuracy:
#     background [███████████████████░]  96.6%
#           buah [███████████████░░░░░]  78.2%
#    karbohidrat [██████████████████░░]  92.2%
#        protein [████████████████░░░░]  82.8%
#          sayur [████████████████░░░░]  83.1%
#           susu [██████████████████░░]  94.5%
# Epoch  35/50 | Loss: 0.0796 | Val Loss: 0.2337 | mIoU: 0.9624 | Val mIoU: 0.7942 | LR: 2.40e-05
#
# [Epoch 35] Per-Class Accuracy:
#     background [███████████████████░]  96.1%
#           buah [███████████████░░░░░]  77.7%
#    karbohidrat [██████████████████░░]  91.7%
#        protein [████████████████░░░░]  83.8%
#          sayur [████████████████░░░░]  84.8%
#           susu [███████████████████░]  95.6%
# Epoch  36/50 | Loss: 0.0765 | Val Loss: 0.2307 | mIoU: 0.9646 | Val mIoU: 0.7962 | LR: 2.14e-05
#
# [Epoch 36] Per-Class Accuracy:
#     background [███████████████████░]  96.2%
#           buah [███████████████░░░░░]  78.6%
#    karbohidrat [██████████████████░░]  92.2%
#        protein [████████████████░░░░]  82.2%
#          sayur [█████████████████░░░]  85.8%
#           susu [███████████████████░]  95.2%
# Epoch  37/50 | Loss: 0.0751 | Val Loss: 0.2304 | mIoU: 0.9656 | Val mIoU: 0.7970 | LR: 1.89e-05
#
# [Epoch 37] Per-Class Accuracy:
#     background [███████████████████░]  95.9%
#           buah [████████████████░░░░]  80.5%
#    karbohidrat [██████████████████░░]  92.9%
#        protein [████████████████░░░░]  83.1%
#          sayur [█████████████████░░░]  85.4%
#           susu [███████████████████░]  95.5%
# Epoch  38/50 | Loss: 0.0737 | Val Loss: 0.2343 | mIoU: 0.9672 | Val mIoU: 0.7952 | LR: 1.66e-05
#
# [Epoch 38] Per-Class Accuracy:
#     background [███████████████████░]  95.8%
#           buah [███████████████░░░░░]  79.4%
#    karbohidrat [██████████████████░░]  92.7%
#        protein [████████████████░░░░]  83.9%
#          sayur [████████████████░░░░]  84.9%
#           susu [███████████████████░]  95.6%
# Epoch  39/50 | Loss: 0.0720 | Val Loss: 0.2314 | mIoU: 0.9687 | Val mIoU: 0.7964 | LR: 1.44e-05
#
# [Epoch 39] Per-Class Accuracy:
#     background [███████████████████░]  96.0%
#           buah [███████████████░░░░░]  79.7%
#    karbohidrat [██████████████████░░]  92.9%
#        protein [████████████████░░░░]  82.7%
#          sayur [█████████████████░░░]  85.2%
#           susu [███████████████████░]  95.3%
# Epoch  40/50 | Loss: 0.0712 | Val Loss: 0.2279 | mIoU: 0.9702 | Val mIoU: 0.7998 | LR: 1.24e-05
#
# [Epoch 40] Per-Class Accuracy:
#     background [███████████████████░]  96.1%
#           buah [████████████████░░░░]  80.3%
#    karbohidrat [██████████████████░░]  92.5%
#        protein [████████████████░░░░]  82.6%
#          sayur [█████████████████░░░]  86.2%
#           susu [███████████████████░]  95.4%
# Epoch  41/50 | Loss: 0.0695 | Val Loss: 0.2293 | mIoU: 0.9710 | Val mIoU: 0.7976 | LR: 1.05e-05
#
# [Epoch 41] Per-Class Accuracy:
#     background [███████████████████░]  96.3%
#           buah [███████████████░░░░░]  78.7%
#    karbohidrat [██████████████████░░]  92.3%
#        protein [████████████████░░░░]  83.6%
#          sayur [████████████████░░░░]  84.4%
#           susu [███████████████████░]  95.3%
# Epoch  42/50 | Loss: 0.0685 | Val Loss: 0.2271 | mIoU: 0.9727 | Val mIoU: 0.8007 | LR: 8.71e-06
#
# [Epoch 42] Per-Class Accuracy:
#     background [███████████████████░]  96.4%
#           buah [███████████████░░░░░]  78.7%
#    karbohidrat [██████████████████░░]  92.3%
#        protein [████████████████░░░░]  82.7%
#          sayur [█████████████████░░░]  85.6%
#           susu [███████████████████░]  95.3%
#
#   Early stopping setelah 10 epoch tanpa perbaikan.

# %% [markdown]
# ## Visualisasi Hasil Training & TensorBoard

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history['train_loss'], label='Train Loss', color='#E74C3C', linewidth=2)
axes[0].plot(history['val_loss'],   label='Val Loss',   color='#3498DB', linewidth=2, linestyle='--')
axes[0].set_title('Training & Validation Loss', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('DiceBCE Loss')
axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].plot(history['train_miou'], label='Train mIoU', color='#2ECC71', linewidth=2)
axes[1].plot(history['val_miou'],   label='Val mIoU',   color='#9B59B6', linewidth=2, linestyle='--')
axes[1].set_title('Training & Validation mIoU', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Mean IoU')
axes[1].legend(); axes[1].grid(alpha=0.3)

plt.suptitle('Kurva Training Model U-Net MBG', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('training_history.png', dpi=150, bbox_inches='tight')
plt.show()
print('Plot tersimpan: training_history.png')
# Out:
# Plot tersimpan: training_history.png

# %%
# Launch TensorBoard
# %load_ext tensorboard
# %tensorboard --logdir {LOG_DIR}

# %% [markdown]
# ## Simpan & Load Model

# %%
# Simpan model final
FINAL_MODEL_PATH = 'models/unet_mbg_final.keras'
model.save(FINAL_MODEL_PATH)
print(f'Model final .keras tersimpan: {FINAL_MODEL_PATH}')

SAVED_MODEL_PATH = 'models/unet_mbg_savedmodel'
model.export(SAVED_MODEL_PATH)
print(f'SavedModel tersimpan       : {SAVED_MODEL_PATH}')

# Verifikasi load ulang
print('\nMemverifikasi load model...')
loaded_model = keras.models.load_model(
    FINAL_MODEL_PATH,
    custom_objects={
        'DiceBCELoss'  : DiceBCELoss,
        'AttentionGate': AttentionGate,
        'ConvBnRelu'   : ConvBnRelu,
        'MeanIoU'      : MeanIoU
    }
)
print(f'Output shape: {loaded_model.output_shape}')
# Out:
# Model final .keras tersimpan: models/unet_mbg_final.keras
# Saved artifact at 'models/unet_mbg_savedmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='input_image')
# Output Type:
#   TensorSpec(shape=(None, 256, 256, 6), dtype=tf.float32, name=None)
# Captures:
#   139399789510288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115522704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115522896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399789509904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399789509712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399789509520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115524240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115525008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115524624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115523280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115523472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115526160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115526352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115523856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115524048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115526928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115529040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115529232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115528080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115527504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115525968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115530384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115530576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115529808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115527312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115529424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115527888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115528848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115530000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115531536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115530960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115531152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115531344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115530192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115532496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115531920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115532112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115532304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115528272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115533456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115533840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115534032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115533072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115533648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115534608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115534992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115535184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115534224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115534800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115535760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115533264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115535376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115535568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115532688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115536720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115536144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115536336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115536528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115532880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115537680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115537104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115537296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115537872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115538256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115536912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115535952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115537488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119471056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115538064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399115534416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119470864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119471632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119471440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119471248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119472784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119472208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119472400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119472592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119471824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119473744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119473168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119473360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119473552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119470672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119474704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119474128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119474320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119474512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119472016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119475664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119475088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119475280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119475472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119472976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119476624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119476048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119476240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119476432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119473936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119477584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119477008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119477200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119477392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119474896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119478544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119477968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119478160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119478352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119475856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119479504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119478928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119479120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119479312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119476816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119480464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119479888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119480080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119480272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119477776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119481424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119480848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119481040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119481232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119478736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119482384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119481808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119482000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119482192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119479696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119483344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119482768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119482960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119483152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119480656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119484304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119483728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119483920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119484112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119481616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119485264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119484688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119484880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119485072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119482576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119486224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119485648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119485840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119486416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119486800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119485456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119484496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119486032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071089872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119486608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399119483536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071089488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071088912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071088720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071089104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071090832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071090256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071090448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071090640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071089680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071091792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071091216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071091408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071091600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071089296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071092752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071092176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071092368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071092560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071090064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071093712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071093136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071093328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071093520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071091024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071094672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071094096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071094288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071094480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071091984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071095632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071095056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071095248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071095440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071092944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071096592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071096016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071096208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071096400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071093904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071097552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071096976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071097168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071097360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071094864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071098512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071097936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071098128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071098320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071095824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071099472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071098896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071099088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071099280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071096784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071100432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071099856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071100048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071100240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071097744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071101392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071100816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071101008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071101200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071098704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071102352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071101776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071101968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071102160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071099664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071103312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071102736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071102928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071103120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071100624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071104272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071103696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071103888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071104464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071104848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071103504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071102544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071104080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117014224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071104656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399071101584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117013840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117013264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117013072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117013456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117015184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117014608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117014800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117014992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117014032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117016144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117015568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117017872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117019216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117019408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117020560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117020752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117018832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117019600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117020368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117021520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117021712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117019024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117019984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117019792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117020944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117022480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117021904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117022096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117022288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117020176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117023440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117022864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117023056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117023248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117021136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117024400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117015376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117022672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117024592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117025360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117025552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117024976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117023824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117025168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117026512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117026704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117023632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117024208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117025936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117024784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117027472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117026896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117027088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117027280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117024016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117028432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117027856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117029200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117028816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117028624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117027664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117018640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117026320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117021328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117028048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117028240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117025744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806537232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806537040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139399117029008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806538384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806536656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806536848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806537808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806536272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806539152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806538576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806538768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806538960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806536464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806540112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806539536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806539728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806539920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806538192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806541072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806537616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806539344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806541264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806542032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806542224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806541456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806541840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806541648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806543184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806543376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806542416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806540880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806542608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806538000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806544144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806543568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806543760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806543952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806540688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806545104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806544528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806544720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806544912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806542800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806546064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806537424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806544336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806546256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806547024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806547216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806546448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806546832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806546640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806548176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806548368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806547408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806545680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806547984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806549136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806549328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806540304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139398806547792: TensorSpec(shape=(), dtype=tf.resource, name=None)
# SavedModel tersimpan       : models/unet_mbg_savedmodel
#
# Memverifikasi load model...
# `build()` was called on layer 'bridge_conv1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'bridge_conv2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec1_attn', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec1_conv1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec1_conv2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec2_attn', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec2_conv1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec2_conv2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec3_attn', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec3_conv1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec3_conv2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec4_attn', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec4_conv1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec4_conv2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'head_conv', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# Output shape: (None, 256, 256, 6)

# %% [markdown]
# ## Evaluasi Model

# %%
def evaluate_model(model, dataset, class_mapping=CLASS_MAPPING,
                   num_classes=NUM_CLASSES):
    """Evaluasi loss, mIoU, dan per-class IoU pada dataset."""
    iou_per_class = np.zeros(num_classes)
    total_loss    = []
    count_per_cls = np.zeros(num_classes)

    for x_batch, y_batch in dataset:
        y_pred   = model(x_batch, training=False)
        loss     = loss_fn(y_batch, y_pred)
        total_loss.append(float(loss))
        pred_cls = tf.argmax(y_pred,  axis=-1).numpy()
        true_cls = tf.argmax(y_batch, axis=-1).numpy()

        for c in range(num_classes):
            inter = np.sum((pred_cls == c) & (true_cls == c))
            union = np.sum((pred_cls == c) | (true_cls == c))
            if union > 0:
                iou_per_class[c] += inter / union
                count_per_cls[c] += 1

    iou_per_class = np.where(count_per_cls > 0,
                             iou_per_class / count_per_cls, 0)
    mean_iou = np.mean(iou_per_class[1:])   # skip background

    print('='*55)
    print('Hasil Evaluasi Model')
    print(f'\nVal Loss (DiceBCE) : {np.mean(total_loss):.4f}')
    print(f'Mean IoU (non-bg)  : {mean_iou:.4f} ({mean_iou*100:.2f}%)')
    print('\n  Per-Class IoU:')
    for c, (name, iou) in enumerate(zip(class_mapping.values(), iou_per_class)):
        if c == 0: continue
        bar = '█' * int(iou * 25) + '░' * (25 - int(iou * 25))
        print(f'    {name:>12s} [{bar}] {iou*100:5.1f}%')
    print('='*55)
    return iou_per_class, mean_iou


# Evaluasi pada validation set
print("── Validation Set ──")
iou_per_class_val, mean_iou_val = evaluate_model(loaded_model, val_ds)

# Evaluasi pada test set
print("\n── Test Set ──")
iou_per_class_test, mean_iou_test = evaluate_model(loaded_model, test_ds)
# Out:
# ── Validation Set ──
# =======================================================
# Hasil Evaluasi Model
#
# Val Loss (DiceBCE) : 0.2271
# Mean IoU (non-bg)  : 0.7773 (77.73%)
#
#   Per-Class IoU:
#             buah [█████████████████░░░░░░░░]  69.9%
#      karbohidrat [█████████████████████░░░░]  86.7%
#          protein [████████████████░░░░░░░░░]  66.8%
#            sayur [██████████████████░░░░░░░]  75.2%
#             susu [██████████████████████░░░]  90.0%
# =======================================================
#
# ── Test Set ──
# =======================================================
# Hasil Evaluasi Model
#
# Val Loss (DiceBCE) : 0.1986
# Mean IoU (non-bg)  : 0.7922 (79.22%)
#
#   Per-Class IoU:
#             buah [███████████████████░░░░░░]  76.1%
#      karbohidrat [█████████████████████░░░░]  87.9%
#          protein [█████████████████░░░░░░░░]  71.2%
#            sayur [██████████████████░░░░░░░]  73.5%
#             susu [█████████████████████░░░░]  87.4%
# =======================================================

# %%
def visualize_predictions(model, dataset, class_mapping, class_colors, n=3):
    """Tampilkan input | ground truth | prediksi untuk n sampel."""
    fig, axes = plt.subplots(n, 3, figsize=(14, 4*n))
    if n == 1: axes = axes[np.newaxis, :]

    def to_color(mask):
        colored = np.zeros((*mask.shape, 3))
        for c, col in class_colors.items():
            colored[mask == c] = np.array(col) / 255.0
        return colored

    for i, (x_batch, y_batch) in enumerate(dataset.take(n)):
        img  = x_batch[0].numpy()
        true = tf.argmax(y_batch[0], axis=-1).numpy()
        pred = tf.argmax(model(x_batch[:1], training=False)[0], axis=-1).numpy()

        axes[i, 0].imshow(img);              axes[i, 0].set_title('Input',          fontweight='bold')
        axes[i, 1].imshow(to_color(true));   axes[i, 1].set_title('Ground Truth',   fontweight='bold')
        axes[i, 2].imshow(to_color(pred));   axes[i, 2].set_title('Prediksi Model', fontweight='bold')
        for ax in axes[i]: ax.axis('off')

    patches = [mpatches.Patch(color=np.array(c)/255, label=class_mapping[i])
               for i, c in class_colors.items() if i > 0]
    fig.legend(handles=patches, loc='lower center', ncol=len(patches),
               fontsize=10, bbox_to_anchor=(0.5, -0.02))

    plt.suptitle('Hasil Segmentasi U-Net pada Ompreng MBG',
                 fontsize=15, fontweight='bold', y=1.02)
    plt.tight_layout()
    plt.savefig('segmentation_results.png', dpi=150, bbox_inches='tight')
    plt.show()


visualize_predictions(loaded_model, val_ds, CLASS_MAPPING, CLASS_COLORS)

# %% [markdown]
# ## Fuzzy Logic Classifier

# %%
def compute_nutrisi_proportion(pred_mask: np.ndarray,
                                class_mapping: dict,
                                nutrisi_mapping: dict) -> dict:
    """
    Hitung proporsi (%) tiap kategori nutrisi dari mask prediksi.
    """
    pixel_per_class: dict = {}
    for cls_id, food_name in class_mapping.items():
        if cls_id == 0 or food_name not in nutrisi_mapping:
            continue   # skip background & ompreng
        pixel_count = np.sum(pred_mask == cls_id)
        if pixel_count > 0:
            pixel_per_class[food_name] = pixel_count

    total_food_pixels = sum(pixel_per_class.values())
    if total_food_pixels == 0:
        return {'karbo': 0.0, 'protein': 0.0, 'serat': 0.0, 'susu': 0.0}

    # Akumulasi piksel per kategori nutrisi
    nutrisi_pixels = {'karbo': 0, 'protein': 0, 'serat': 0, 'susu': 0}
    for food_name, pixels in pixel_per_class.items():
        nutrisi_cat = nutrisi_mapping[food_name]
        nutrisi_pixels[nutrisi_cat] += pixels

    # Proporsi (%)
    nutrisi_prop = {
        k: round(v / total_food_pixels * 100, 1)
        for k, v in nutrisi_pixels.items()
    }

    print('\n  Detail Piksel per Kelas Makanan:')
    for food, pix in pixel_per_class.items():
        nutr = nutrisi_mapping[food]
        pct  = pix / total_food_pixels * 100
        print(f'    {food:>12s} → {nutr:<8s}: {pix:>6d} piksel ({pct:5.1f}%)')
    print(f'    Total food pixels: {total_food_pixels}')

    return nutrisi_prop

# %%
class FuzzyNutritionClassifier:
    """
    Fuzzy Logic Classifier untuk status gizi ompreng MBG.
    Input  : proporsi karbo, protein, serat, susu (0-100 %)
    Output : status gizi + healthy score (0-100)
    """

    STATUS_LABELS = {
        (80, 101): 'seimbang',
        (60,  80): 'cukup_seimbang',
        (40,  60): 'kurang_seimbang',
        (20,  40): 'tidak_seimbang',
        (0,   20): 'sangat_tidak_seimbang'
    }

    def __init__(self):
        self._build_system()

    def _build_system(self):
        # Universe of discourse
        self.karbo   = ctrl.Antecedent(np.arange(0, 101, 1), 'karbo')
        self.protein = ctrl.Antecedent(np.arange(0, 101, 1), 'protein')
        self.serat   = ctrl.Antecedent(np.arange(0, 101, 1), 'serat')
        self.susu    = ctrl.Antecedent(np.arange(0, 101, 1), 'susu')
        self.score   = ctrl.Consequent(np.arange(0, 101, 1), 'score')

        # MF: Karbohidrat
        self.karbo['rendah'] = fuzz.trimf(self.karbo.universe, [0,   0,  40])
        self.karbo['sedang'] = fuzz.trimf(self.karbo.universe, [30,  50, 70])
        self.karbo['tinggi'] = fuzz.trimf(self.karbo.universe, [60, 100, 100])

        # MF: Protein
        self.protein['kurang'] = fuzz.trimf(self.protein.universe, [0,   0,  20])
        self.protein['cukup']  = fuzz.trimf(self.protein.universe, [15,  25, 35])
        self.protein['lebih']  = fuzz.trimf(self.protein.universe, [30, 100, 100])

        # MF: Serat (sayur + buah)
        self.serat['kurang'] = fuzz.trimf(self.serat.universe, [0,   0,  20])
        self.serat['cukup']  = fuzz.trimf(self.serat.universe, [15,  25, 40])
        self.serat['lebih']  = fuzz.trimf(self.serat.universe, [35, 100, 100])

        # MF: Susu — ada/tidak ada (khas MBG)
        self.susu['tidak_ada'] = fuzz.trimf(self.susu.universe, [0,   0,  5])
        self.susu['ada']       = fuzz.trimf(self.susu.universe, [3,  100, 100])

        # MF: Score output
        self.score['sangat_buruk'] = fuzz.trimf(self.score.universe, [0,   0,  20])
        self.score['buruk']        = fuzz.trimf(self.score.universe, [10,  25, 40])
        self.score['sedang']       = fuzz.trimf(self.score.universe, [30,  50, 70])
        self.score['baik']         = fuzz.trimf(self.score.universe, [60,  75, 90])
        self.score['sangat_baik']  = fuzz.trimf(self.score.universe, [80, 100, 100])

        # Fuzzy Rules
        rules = [
            # Komposisi ideal: karbo sedang + protein cukup + serat cukup + ada susu
            ctrl.Rule(self.karbo['sedang']  & self.protein['cukup'] &
                      self.serat['cukup']   & self.susu['ada'],
                      self.score['sangat_baik']),

            ctrl.Rule(self.karbo['sedang']  & self.protein['cukup'] &
                      self.serat['cukup']   & self.susu['tidak_ada'],
                      self.score['baik']),

            # Karbo berlebih
            ctrl.Rule(self.karbo['tinggi'],
                      self.score['buruk']),
            ctrl.Rule(self.karbo['tinggi']  & self.protein['kurang'],
                      self.score['sangat_buruk']),

            # Protein kurang
            ctrl.Rule(self.protein['kurang'],
                      self.score['buruk']),
            ctrl.Rule(self.protein['kurang'] & self.serat['kurang'],
                      self.score['sangat_buruk']),

            # Serat kurang
            ctrl.Rule(self.serat['kurang'],
                      self.score['buruk']),

            # Tanpa susu (komponen wajib MBG)
            ctrl.Rule(self.susu['tidak_ada'] & self.karbo['sedang'] &
                      self.protein['cukup'],
                      self.score['sedang']),

            # Karbo rendah tetapi protein cukup
            ctrl.Rule(self.karbo['rendah']  & self.protein['cukup'],
                      self.score['sedang']),

            # Karbo sedang + protein cukup + serat kurang
            ctrl.Rule(self.karbo['sedang']  & self.protein['cukup'] &
                      self.serat['kurang'],
                      self.score['sedang']),
        ]

        self.ctrl_system = ctrl.ControlSystem(rules)
        self.simulation  = ctrl.ControlSystemSimulation(self.ctrl_system)

    def classify(self, nutrisi: dict) -> dict:
        """Klasifikasi status gizi dari dict proporsi nutrisi."""
        self.simulation.input['karbo']   = np.clip(nutrisi.get('karbo',   0), 0, 100)
        self.simulation.input['protein'] = np.clip(nutrisi.get('protein', 0), 0, 100)
        self.simulation.input['serat']   = np.clip(nutrisi.get('serat',   0), 0, 100)
        self.simulation.input['susu']    = np.clip(nutrisi.get('susu',    0), 0, 100)

        try:
            self.simulation.compute()
            healthy_score = round(self.simulation.output['score'], 1)
        except Exception:
            healthy_score = 50.0

        status = 'tidak_seimbang'
        for (low, high), lbl in self.STATUS_LABELS.items():
            if low <= healthy_score < high:
                status = lbl
                break

        detail = self._rule_based_detail(nutrisi)

        return {
            'healthy_score': healthy_score,
            'status'       : status,
            'detail'       : detail,
            'nutrisi'      : nutrisi
        }

    def _rule_based_detail(self, nutrisi: dict) -> str:
        """Label detail berdasarkan heuristik proporsi nutrisi."""
        k = nutrisi.get('karbo',   0)
        p = nutrisi.get('protein', 0)
        s = nutrisi.get('serat',   0)
        u = nutrisi.get('susu',    0)

        if k > 60:
            return 'tinggi_karbo'
        if p < 15:
            if s < 15:
                return 'protein_dan_serat_kurang'
            return 'protein_kurang'
        if s < 15:
            return 'serat_kurang'
        if u == 0:
            return 'tanpa_susu'
        if 35 <= k <= 65 and p >= 15 and s >= 15 and u > 0:
            return 'seimbang'
        return 'cukup_seimbang'


# Inisialisasi
fuzzy_clf = FuzzyNutritionClassifier()

# Unit Test
test_cases = [
    {'karbo': 60, 'protein': 20, 'serat': 20, 'susu':  0},  # tinggi karbo, tanpa susu
    {'karbo': 50, 'protein': 20, 'serat': 20, 'susu': 10},  # seimbang + susu
    {'karbo': 70, 'protein':  5, 'serat':  5, 'susu':  0},  # buruk
    {'karbo': 40, 'protein': 20, 'serat': 30, 'susu': 10},  # seimbang ideal
]

print('Unit Test Fuzzy Logic Classifier:')
print('='*60)
for tc in test_cases:
    res = fuzzy_clf.classify(tc)
    print(f"  Input  : {tc}")
    print(f"  Status : {res['status']}  |  Detail: {res['detail']}  |  Score: {res['healthy_score']}")
    print('-'*60)
# Out:
# Unit Test Fuzzy Logic Classifier:
# ============================================================
#   Input  : {'karbo': 60, 'protein': 20, 'serat': 20, 'susu': 0}
#   Status : cukup_seimbang  |  Detail: tanpa_susu  |  Score: 60.5
# ------------------------------------------------------------
#   Input  : {'karbo': 50, 'protein': 20, 'serat': 20, 'susu': 10}
#   Status : seimbang  |  Detail: seimbang  |  Score: 90.4
# ------------------------------------------------------------
#   Input  : {'karbo': 70, 'protein': 5, 'serat': 5, 'susu': 0}
#   Status : sangat_tidak_seimbang  |  Detail: tinggi_karbo  |  Score: 18.0
# ------------------------------------------------------------
#   Input  : {'karbo': 40, 'protein': 20, 'serat': 30, 'susu': 10}
#   Status : seimbang  |  Detail: seimbang  |  Score: 90.4
# ------------------------------------------------------------

# %% [markdown]
# ## Inference Pipeline Lengkap

# %%
class MBGNutritionAnalyzer:
    """
    Pipeline lengkap: gambar → segmentasi U-Net → proporsi nutrisi → fuzzy classification.
    """

    STATUS_EMOJI = {
        'seimbang'             : '🟢',
        'cukup_seimbang'       : '🟡',
        'kurang_seimbang'      : '🟠',
        'tidak_seimbang'       : '🔴',
        'sangat_tidak_seimbang': '❌'
    }

    # Warna pie chart per kategori nutrisi
    NUTRISI_COLOR_MAP = {
        'karbo'  : '#F39C12',   # oranye-kuning
        'protein': '#E74C3C',   # merah
        'serat'  : '#2ECC71',   # hijau
        'susu'   : '#3498DB',   # biru
    }

    # Proporsi ideal MBG
    IDEAL_PROPORSI = {'karbo': 50, 'protein': 25, 'serat': 15, 'susu': 10}

    def __init__(self, model, fuzzy_clf, class_mapping, nutrisi_mapping,
                 class_colors, img_size=(IMG_HEIGHT, IMG_WIDTH)):
        self.model           = model
        self.fuzzy_clf       = fuzzy_clf
        self.class_mapping   = class_mapping
        self.nutrisi_mapping = nutrisi_mapping
        self.class_colors    = class_colors
        self.img_size        = img_size

    def preprocess(self, image_path: str) -> np.ndarray:
        img = cv2.imread(str(image_path))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, self.img_size)
        img = img.astype(np.float32) / 255.0
        return img[np.newaxis, ...]   # (1, H, W, C)

    def segment(self, img_tensor: np.ndarray) -> np.ndarray:
        pred = self.model(img_tensor, training=False)
        return tf.argmax(pred[0], axis=-1).numpy()   # (H, W)

    def mask_to_colored(self, mask: np.ndarray) -> np.ndarray:
        colored = np.zeros((*mask.shape, 3), dtype=np.uint8)
        for cls_id, color in self.class_colors.items():
            colored[mask == cls_id] = color
        return colored

    def analyze(self, image_path: str) -> dict:
        img_tensor   = self.preprocess(image_path)
        pred_mask    = self.segment(img_tensor)

        print('\nMenghitung proporsi nutrisi...')
        nutrisi_prop = compute_nutrisi_proportion(
            pred_mask, self.class_mapping, self.nutrisi_mapping
        )
        classification = self.fuzzy_clf.classify(nutrisi_prop)

        return {
            'image_path'    : image_path,
            'img_input'     : (img_tensor[0] * 255).astype(np.uint8),
            'pred_mask'     : pred_mask,
            'colored_mask'  : self.mask_to_colored(pred_mask),
            'nutrisi_prop'  : nutrisi_prop,
            'classification': classification
        }

    def visualize(self, result: dict, save_path: str = None):
        clf    = result['classification']
        nutr   = result['nutrisi_prop']
        score  = clf['healthy_score']
        status = clf['status']
        detail = clf['detail']
        emoji  = self.STATUS_EMOJI.get(status, '⚪')

        fig = plt.figure(figsize=(16, 10))
        fig.patch.set_facecolor('#F8F9FA')
        gs  = fig.add_gridspec(2, 3, hspace=0.35, wspace=0.3)

        # Panel 1: Gambar Input
        ax1 = fig.add_subplot(gs[0, 0])
        ax1.imshow(result['img_input'])
        ax1.set_title('Foto Ompreng', fontweight='bold', fontsize=12)
        ax1.axis('off')

        # Panel 2: Mask Segmentasi
        ax2 = fig.add_subplot(gs[0, 1])
        ax2.imshow(result['colored_mask'])
        patches = [mpatches.Patch(color=np.array(c)/255, label=self.class_mapping[i])
                   for i, c in self.class_colors.items() if i > 0]
        ax2.legend(handles=patches, loc='lower right', fontsize=7)
        ax2.set_title('Segmentasi Makanan', fontweight='bold', fontsize=12)
        ax2.axis('off')

        # Panel 3: Pie Chart Proporsi Nutrisi
        ax3     = fig.add_subplot(gs[0, 2])
        labels  = [k for k, v in nutr.items() if v > 0]
        sizes   = [v for v in nutr.values()   if v > 0]
        pie_colors = [self.NUTRISI_COLOR_MAP.get(l, '#95A5A6') for l in labels]
        if sizes:
            wedges, texts, autotexts = ax3.pie(
                sizes, labels=labels, colors=pie_colors,
                autopct='%1.1f%%', startangle=90,
                wedgeprops={'edgecolor': 'white', 'linewidth': 2}
            )
            for at in autotexts:
                at.set_fontsize(10); at.set_fontweight('bold')
        else:
            ax3.text(0.5, 0.5, 'Tidak ada\nmakanan terdeteksi',
                     ha='center', va='center', transform=ax3.transAxes)
        ax3.set_title('Proporsi Nutrisi', fontweight='bold', fontsize=12)

        # Panel 4: Healthy Score Gauge
        ax4 = fig.add_subplot(gs[1, 0])
        self._draw_gauge(ax4, score)

        # Panel 5: Aktual vs Target Nutrisi
        ax5 = fig.add_subplot(gs[1, 1])
        nutrisi_names  = list(nutr.keys())
        nutrisi_values = list(nutr.values())
        ideal_values   = [self.IDEAL_PROPORSI.get(n, 0) for n in nutrisi_names]
        x = np.arange(len(nutrisi_names))
        w = 0.35
        bars1 = ax5.bar(x - w/2, nutrisi_values, w, label='Aktual',
                        color=[self.NUTRISI_COLOR_MAP.get(n, '#95A5A6') for n in nutrisi_names],
                        alpha=0.85, edgecolor='white')
        bars2 = ax5.bar(x + w/2, ideal_values, w, label='Target Ideal',
                        color='#BDC3C7', alpha=0.7, edgecolor='white')
        ax5.bar_label(bars1, fmt='%.0f%%', fontsize=9, fontweight='bold')
        ax5.set_xticks(x); ax5.set_xticklabels(nutrisi_names, fontsize=10)
        ax5.set_ylabel('Proporsi (%)'); ax5.set_ylim(0, 100)
        ax5.set_title('Aktual vs Target Nutrisi', fontweight='bold', fontsize=12)
        ax5.legend(fontsize=9); ax5.grid(axis='y', alpha=0.3)

        # Panel 6: Status Card
        ax6 = fig.add_subplot(gs[1, 2])
        ax6.axis('off')
        status_color = {
            'seimbang'             : '#2ECC71',
            'cukup_seimbang'       : '#F1C40F',
            'kurang_seimbang'      : '#E67E22',
            'tidak_seimbang'       : '#E74C3C',
            'sangat_tidak_seimbang': '#C0392B'
        }.get(status, '#95A5A6')

        ax6.add_patch(plt.Rectangle((0, 0), 1, 1, transform=ax6.transAxes,
                                     color=status_color, alpha=0.15, clip_on=False))
        ax6.text(0.5, 0.85, f'{emoji} STATUS OMPRENG', ha='center', va='center',
                 transform=ax6.transAxes, fontsize=13, fontweight='bold')
        ax6.text(0.5, 0.65, status.upper().replace('_', ' '),
                 ha='center', va='center', transform=ax6.transAxes,
                 fontsize=16, fontweight='bold', color=status_color)
        ax6.text(0.5, 0.48, f'Detail: {detail.replace("_", " ")}',
                 ha='center', va='center', transform=ax6.transAxes,
                 fontsize=11, color='#555')
        ax6.text(0.5, 0.30, f'Healthy Score: {score:.0f}/100',
                 ha='center', va='center', transform=ax6.transAxes,
                 fontsize=14, fontweight='bold',
                 color='#27AE60' if score >= 70 else '#E74C3C')
        rec = self._get_recommendation(detail)
        ax6.text(0.5, 0.12, rec, ha='center', va='center',
                 transform=ax6.transAxes, fontsize=9, color='#333',
                 wrap=True, style='italic')

        plt.suptitle('Laporan Analisis Gizi Ompreng MBG',
                     fontsize=18, fontweight='bold', y=1.01)
        if save_path:
            plt.savefig(save_path, dpi=150, bbox_inches='tight',
                        facecolor=fig.get_facecolor())
            print(f'\nHasil tersimpan: {save_path}')
        plt.show()

    @staticmethod
    def _draw_gauge(ax, score: float):
        for t1, t2, c in [
            (np.pi,     np.pi*0.8, '#E74C3C'),
            (np.pi*0.8, np.pi*0.6, '#E67E22'),
            (np.pi*0.6, np.pi*0.4, '#F1C40F'),
            (np.pi*0.4, np.pi*0.2, '#2ECC71'),
            (np.pi*0.2, 0,         '#27AE60'),
        ]:
            thetas = np.linspace(t1, t2, 50)
            ax.plot(np.cos(thetas), np.sin(thetas), linewidth=15,
                    color=c, solid_capstyle='butt', alpha=0.8)

        angle = np.pi - (score / 100) * np.pi
        ax.annotate('', xy=(0.7*np.cos(angle), 0.7*np.sin(angle)),
                    xytext=(0, 0),
                    arrowprops=dict(arrowstyle='->', lw=3, color='#2C3E50'))
        ax.plot(0, 0, 'o', color='#2C3E50', markersize=12)
        ax.text(0, -0.35, f'{score:.0f}', ha='center', fontsize=22,
                fontweight='bold', color='#2C3E50')
        ax.text(0, -0.55, 'Healthy Score', ha='center', fontsize=10, color='#666')
        ax.set_xlim(-1.2, 1.2); ax.set_ylim(-0.7, 1.2)
        ax.set_aspect('equal'); ax.axis('off')
        ax.set_title('Healthy Score', fontweight='bold', fontsize=12)

    @staticmethod
    def _get_recommendation(detail: str) -> str:
        recs = {
            'seimbang'                 : 'Pertahankan komposisi gizi yang sudah baik ini!',
            'cukup_seimbang'           : 'Tambahkan sedikit lebih banyak sayur atau buah.',
            'tinggi_karbo'             : 'Kurangi porsi karbohidrat, perbanyak sayur & protein.',
            'protein_kurang'           : 'Tambahkan lauk protein (ayam/ikan/tempe/telur).',
            'serat_kurang'             : 'Perbanyak sayuran hijau dan buah-buahan.',
            'tanpa_susu'               : 'Lengkapi dengan susu sebagai sumber kalsium & protein.',
            'protein_dan_serat_kurang' : 'Tambahkan lauk protein dan porsi sayur/buah.',
        }
        return recs.get(detail, 'Konsultasikan dengan ahli gizi untuk saran lebih lanjut.')

# %% [markdown]
# ## Jalankan Inference pada Gambar Test

# %%
# Inisialisasi analyzer
analyzer = MBGNutritionAnalyzer(
    model          = loaded_model,
    fuzzy_clf      = fuzzy_clf,
    class_mapping  = CLASS_MAPPING,
    nutrisi_mapping= NUTRISI_MAPPING,
    class_colors   = CLASS_COLORS
)

# Pilih beberapa gambar dari test set
test_images = list(IMAGES_TEST.glob('*.[jp][pn]g'))[:3]
if not test_images:
    # Fallback ke train jika test kosong
    test_images = random.sample(list(IMAGES_TRAIN.glob('*.[jp][pn]g')), 3)

for i, img_path in enumerate(test_images):
    print(f"\n{'='*65}")
    print(f'Analisis Ompreng #{i+1}: {img_path.name}')
    print('='*65)

    result = analyzer.analyze(str(img_path))
    clf    = result['classification']

    print('\nProporsi Nutrisi:')
    for nutr, pct in result['nutrisi_prop'].items():
        print(f'    {nutr:>10s}: {pct:5.1f}%')

    print('\nHasil Klasifikasi:')
    print(f'  Status        : {clf["status"]}')
    print(f'  Detail        : {clf["detail"]}')
    print(f'  Healthy Score : {clf["healthy_score"]}/100')

    analyzer.visualize(result, save_path=f'hasil_ompreng_{i+1}.png')
# Out:
# =================================================================
# Analisis Ompreng #1: mbg_1768233175_b1f854da_jpg.rf.3431d82c0a94563fdacba7358ffedb62.jpg
# =================================================================
#
# Menghitung proporsi nutrisi...
#
#   Detail Piksel per Kelas Makanan:
#             buah → serat   :   3821 piksel ( 17.4%)
#      karbohidrat → karbo   :   7346 piksel ( 33.4%)
#          protein → protein :   5810 piksel ( 26.4%)
#            sayur → serat   :   5019 piksel ( 22.8%)
#     Total food pixels: 21996
#
# Proporsi Nutrisi:
#          karbo:  33.4%
#        protein:  26.4%
#          serat:  40.2%
#           susu:   0.0%
#
# Hasil Klasifikasi:
#   Status        : kurang_seimbang
#   Detail        : tanpa_susu
#   Healthy Score : 50.0/100
# Glyph 128992 (\N{LARGE ORANGE CIRCLE}) missing from font(s) DejaVu Sans.
# Hasil tersimpan: hasil_ompreng_1.png
# Glyph 128992 (\N{LARGE ORANGE CIRCLE}) missing from font(s) DejaVu Sans.
# =================================================================
# Analisis Ompreng #2: 11_611006080_17866153689544624_2092576985898413342_n_jpg.rf.203aaeac999dc6b6521b704dfb512639.jpg
# =================================================================
#
# Menghitung proporsi nutrisi...
#
#   Detail Piksel per Kelas Makanan:
#             buah → serat   :   4581 piksel ( 19.3%)
#      karbohidrat → karbo   :   6645 piksel ( 27.9%)
#          protein → protein :   4454 piksel ( 18.7%)
#            sayur → serat   :   3279 piksel ( 13.8%)
#             susu → susu    :   4818 piksel ( 20.3%)
#     Total food pixels: 23777
#
# Proporsi Nutrisi:
#          karbo:  27.9%
#        protein:  18.7%
#          serat:  33.1%
#           susu:  20.3%
#
# Hasil Klasifikasi:
#   Status        : kurang_seimbang
#   Detail        : cukup_seimbang
#   Healthy Score : 46.7/100
# Glyph 128992 (\N{LARGE ORANGE CIRCLE}) missing from font(s) DejaVu Sans.
# Hasil tersimpan: hasil_ompreng_2.png
# Glyph 128992 (\N{LARGE ORANGE CIRCLE}) missing from font(s) DejaVu Sans.
# =================================================================
# Analisis Ompreng #3: 42_590420604_17862303636549537_3287437404451747157_n_jpg.rf.a98572f59bf3b1b548e5a56c40c8a4c1.jpg
# =================================================================
#
# Menghitung proporsi nutrisi...
#
#   Detail Piksel per Kelas Makanan:
#             buah → serat   :   1268 piksel (  6.0%)
#      karbohidrat → karbo   :   2060 piksel (  9.7%)
#          protein → protein :   3771 piksel ( 17.8%)
#            sayur → serat   :  14083 piksel ( 66.5%)
#     Total food pixels: 21182
#
# Proporsi Nutrisi:
#          karbo:   9.7%
#        protein:  17.8%
#          serat:  72.5%
#           susu:   0.0%
#
# Hasil Klasifikasi:
#   Status        : kurang_seimbang
#   Detail        : tanpa_susu
#   Healthy Score : 44.5/100
# Glyph 128992 (\N{LARGE ORANGE CIRCLE}) missing from font(s) DejaVu Sans.
# Hasil tersimpan: hasil_ompreng_3.png
# Glyph 128992 (\N{LARGE ORANGE CIRCLE}) missing from font(s) DejaVu Sans.

# %% [markdown]
# ## Demo Inference dari Custom Input

# %%
def predict_ompreng(image_path: str,
                    model_path: str = FINAL_MODEL_PATH,
                    return_json: bool = False) -> dict:
    """
    Fungsi inference siap produksi untuk satu gambar ompreng.

    Args:
        image_path  : path gambar (jpg/png)
        model_path  : path file .keras
        return_json : True → kembalikan dict JSON-serializable

    Returns:
        dict hasil analisis lengkap
    """
    seg_model = keras.models.load_model(
        model_path,
        custom_objects={
            'DiceBCELoss'  : DiceBCELoss,
            'AttentionGate': AttentionGate,
            'ConvBnRelu'   : ConvBnRelu,
            'MeanIoU'      : MeanIoU
        }
    )
    fz_clf = FuzzyNutritionClassifier()
    anlzr  = MBGNutritionAnalyzer(
        model          = seg_model,
        fuzzy_clf      = fz_clf,
        class_mapping  = CLASS_MAPPING,
        nutrisi_mapping= NUTRISI_MAPPING,
        class_colors   = CLASS_COLORS
    )

    result = anlzr.analyze(image_path)

    if return_json:
        return {
            'image_path'   : image_path,
            'nutrisi_prop' : result['nutrisi_prop'],
            'status'       : result['classification']['status'],
            'detail'       : result['classification']['detail'],
            'healthy_score': result['classification']['healthy_score'],
            'rekomendasi'  : MBGNutritionAnalyzer._get_recommendation(
                                result['classification']['detail'])
        }

    anlzr.visualize(result)
    return result


# Contoh penggunaan
sample_img  = str(test_images[0])
json_result = predict_ompreng(sample_img, return_json=True)

print('\nOutput JSON Inference:')
print(json.dumps(json_result, indent=2, ensure_ascii=False))
# Out:
# `build()` was called on layer 'bridge_conv1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'bridge_conv2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec1_attn', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec1_conv1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec1_conv2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec2_attn', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec2_conv1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec2_conv2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec3_attn', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec3_conv1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec3_conv2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec4_attn', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec4_conv1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'dec4_conv2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# `build()` was called on layer 'head_conv', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
# Menghitung proporsi nutrisi...
#
#   Detail Piksel per Kelas Makanan:
#             buah → serat   :   3821 piksel ( 17.4%)
#      karbohidrat → karbo   :   7346 piksel ( 33.4%)
#          protein → protein :   5810 piksel ( 26.4%)
#            sayur → serat   :   5019 piksel ( 22.8%)
#     Total food pixels: 21996
#
# Output JSON Inference:
# {
#   "image_path": "Ompreng-MBG-Fix-2/test/mbg_1768233175_b1f854da_jpg.rf.3431d82c0a94563fdacba7358ffedb62.jpg",
#   "nutrisi_prop": {
#     "karbo": 33.4,
#     "protein": 26.4,
#     "serat": 40.2,
#     "susu": 0.0
#   },
#   "status": "kurang_seimbang",
#   "detail": "tanpa_susu",
#   "healthy_score": 50.0,
#   "rekomendasi": "Lengkapi dengan susu sebagai sumber kalsium & protein."
# }
